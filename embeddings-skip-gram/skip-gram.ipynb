# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils
from collections import Counter

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ### Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'of', 'the', 'french', 'revolution', 'whilst', 'the']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16426833
# Unique words: 36074

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
word_counts, vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %%
word_counts.most_common(10)
# Out:
# [('the', 1061396),
#  ('of', 593677),
#  ('and', 416629),
#  ('one', 411764),
#  ('in', 372201),
#  ('a', 325873),
#  ('to', 316376),
#  ('zero', 264975),
#  ('nine', 250430),
#  ('two', 192644)]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
thresh = 1e-5
total_count = len(int_words)

prob_words = Counter()

for word in word_counts:
    
    freq = word_counts[word]/total_count
    prob_words[word] = 1 - np.sqrt(thresh/freq)

# %%
prob_words.most_common()
# Out:
# [('the', 0.9875594896267594),
#  ('of', 0.9833658042085255),
#  ('and', 0.9801435241072592),
#  ('one', 0.9800265662253344),
#  ('in', 0.9789918333823622),
#  ('a', 0.9775481190040227),
#  ('to', 0.9772136294501936),
#  ('zero', 0.9751014262381349),
#  ('nine', 0.9743885749237265),
#  ('two', 0.970798902297044),
#  ('is', 0.9700518566917413),
#  ('as', 0.964698390706541),
#  ('eight', 0.9637900952558502),
#  ('for', 0.9627592383287111),
#  ('s', 0.9624834506571414),
#  ('five', 0.9623345405505647),
#  ('three', 0.9621685253414293),
#  ('was', 0.9618399534207789),
#  ('by', 0.9616737951267327),
#  ('that', 0.9612697739719751),
#  ('four', 0.9610327804957538),
#  ('six', 0.9598977846698658),
#  ('seven', 0.9594055771599679),
#  ('with', 0.9585484131638763),
#  ('on', 0.9575712258400937),
#  ('are', 0.9536692237413713),
#  ('it', 0.9526713372451667),
#  ('from', 0.9525212194095174),
#  ('or', 0.95118812021256),
#  ('his', 0.948775308891879),
#  ('an', 0.9484956496736111),
#  ('be', 0.948225728213013),
#  ('this', 0.9471591111067728),
#  ('which', 0.9452436869876728),
#  ('at', 0.9451374398545165),
#  ('he', 0.9446262497513339),
#  ('also', 0.9391457460218106),
#  ('not', 0.9389215815000193),
#  ('have', 0.9356844421225108),
#  ('were', 0.9351714501235209),
#  ('has', 0.9341353776984656),
#  ('but', 0.9318394517130358),
#  ('other', 0.928832229625356),
#  ('their', 0.927812309109433),
#  ('its', 0.9254627629359984),
#  ('first', 0.9244898571513058),
#  ('they', 0.9241507923509801),
#  ('some', 0.9236247078159082),
#  ('had', 0.9235418543077023),
#  ('all', 0.920861820693193),
#  ('more', 0.9208527675353178),
#  ('most', 0.9198375446573192),
#  ('can', 0.9197684661479264),
#  ('been', 0.9195538163445867),
#  ('such', 0.9179712024295589),
#  ('many', 0.9174333919134597),
#  ('who', 0.9172632522927228),
#  ('new', 0.916869129132389),
#  ('used', 0.9150016803562475),
#  ('there', 0.91494554991386),
#  ('after', 0.9118182806852703),
#  ('when', 0.9107514846992268),
#  ('into', 0.9104491860906786),
#  ('american', 0.9104338810622481),
#  ('time', 0.9102913871772634),
#  ('these', 0.9090623833563822),
#  ('only', 0.9081303568009551),
#  ('see', 0.9075177347565095),
#  ('may', 0.9072978578635681),
#  ('than', 0.9065418545649573),
#  ('world', 0.9043341813650799),
#  ('i', 0.9033381430469403),
#  ('b', 0.9031589582276914),
#  ('would', 0.9027724101117194),
#  ('d', 0.9023755324345365),
#  ('no', 0.899162181933262),
#  ('however', 0.8982319065431198),
#  ('between', 0.8978317514102868),
#  ('about', 0.8972984883850641),
#  ('over', 0.8957749039241021),
#  ('years', 0.8951244364500018),
#  ('states', 0.895057662463797),
#  ('people', 0.8942750838576625),
#  ('war', 0.8940332533390392),
#  ('during', 0.8938480569576731),
#  ('united', 0.8935408994704884),
#  ('known', 0.8933309461922352),
#  ('if', 0.8932680876702285),
#  ('called', 0.8922584161662525),
#  ('use', 0.891721469164882),
#  ('th', 0.8891976773324666),
#  ('system', 0.8888482210655682),
#  ('often', 0.8875336758906291),
#  ('state', 0.8871725575354399),
#  ('so', 0.8863683729103068),
#  ('history', 0.8859236466120978),
#  ('will', 0.8856379053433021),
#  ('up', 0.8851107298511324),
#  ('while', 0.8847303468444225),
#  ('where', 0.8846556842809107),
#  ('city', 0.8843178982030017),
#  ('being', 0.8826620495361386),
#  ('english', 0.882351023814173),
#  ('then', 0.8822467976552392),
#  ('any', 0.8820275177588974),
#  ('both', 0.8817869005654437),
#  ('under', 0.8817768428720206),
#  ('out', 0.8816155698399254),
#  ('made', 0.8815144384101039),
#  ('well', 0.8806752660607627),
#  ('her', 0.8806700943310414),
#  ('e', 0.8800970657758201),
#  ('number', 0.8799551469911182),
#  ('government', 0.8795529500951274),
#  ('them', 0.8793503297431069),
#  ('m', 0.8776638322599658),
#  ('later', 0.8776359582666354),
#  ('since', 0.8760439420870006),
#  ('him', 0.875682943831439),
#  ('part', 0.8756712461549917),
#  ('name', 0.875348260396607),
#  ('c', 0.8752833606579471),
#  ('century', 0.8752183594437659),
#  ('through', 0.8741461215249202),
#  ('because', 0.8739088161549831),
#  ('x', 0.8737559894149584),
#  ('university', 0.8730644392356419),
#  ('early', 0.8729210127008529),
#  ('life', 0.8724436010820592),
#  ('british', 0.8721901607389588),
#  ('year', 0.870912998146699),
#  ('like', 0.8708868008857792),
#  ('same', 0.87035948319565),
#  ('including', 0.8694141438126315),
#  ('became', 0.8691285315378908),
#  ('example', 0.8687723061951329),
#  ('day', 0.8687379002550527),
#  ('each', 0.868503219971382),
#  ('even', 0.8678899181150181),
#  ('work', 0.8677211591594156),
#  ('language', 0.8676294776016956),
#  ('although', 0.8669966495380065),
#  ('several', 0.8661434526749621),
#  ('form', 0.8658872116136591),
#  ('john', 0.8645684407703547),
#  ('u', 0.8643562367421462),
#  ('national', 0.864173551456319),
#  ('very', 0.8638443860801328),
#  ('much', 0.8635437618885843),
#  ('g', 0.8631632167333692),
#  ('french', 0.862873747213392),
#  ('before', 0.8625903306117823),
#  ('general', 0.8622654002942071),
#  ('what', 0.8616408230091247),
#  ('t', 0.8609094896751793),
#  ('against', 0.8604237191072359),
#  ('n', 0.8599244581323099),
#  ('high', 0.8596307368161412),
#  ('links', 0.8594198010087767),
#  ('could', 0.8593521004515217),
#  ('based', 0.8588412091959845),
#  ('those', 0.8585406060337161),
#  ('now', 0.858514750598529),
#  ('second', 0.8576798168730891),
#  ('de', 0.8567226146675161),
#  ('music', 0.8565881365989314),
#  ('another', 0.8561008615132485),
#  ('large', 0.8557823693383182),
#  ('she', 0.8557641058505401),
#  ('f', 0.8555994216170894),
#  ('external', 0.8554525610875144),
#  ('german', 0.855415775888061),
#  ('different', 0.8548512988671477),
#  ('modern', 0.8547860990751132),
#  ('great', 0.8545993287073432),
#  ('do', 0.8545337886222963),
#  ('common', 0.8539209393104517),
#  ('set', 0.8537688923677156),
#  ('list', 0.8536736215858114),
#  ('south', 0.853252206873069),
#  ('series', 0.8530884096727315),
#  ('major', 0.8528368319775201),
#  ('game', 0.8525254163814944),
#  ('power', 0.8522218394413383),
#  ('long', 0.8518867187909442),
#  ('country', 0.851817439914518),
#  ('king', 0.8515692194315085),
#  ('law', 0.851359747441802),
#  ('group', 0.8511794924037959),
#  ('film', 0.8510086479926671),
#  ('still', 0.8507866793083299),
#  ('until', 0.8506854559599459),
#  ('north', 0.850278492697581),
#  ('international', 0.8495996666929164),
#  ('term', 0.849152401669268),
#  ('we', 0.8480859545246056),
#  ('end', 0.8480325708052521),
#  ('book', 0.848000513547392),
#  ('found', 0.8472792399339201),
#  ('own', 0.8471815680930178),
#  ('political', 0.8464815658866156),
#  ('party', 0.8461833536036252),
#  ('order', 0.8457941830228921),
#  ('usually', 0.8453907955141161),
#  ('president', 0.8453119908028862),
#  ('church', 0.8444141870823194),
#  ('you', 0.8433018525411344),
#  ('death', 0.8432315370125972),
#  ('theory', 0.8422848589457981),
#  ('area', 0.8421293979508793),
#  ('around', 0.8419494473600898),
#  ('include', 0.8414058808605073),
#  ('god', 0.8412478034933893),
#  ('ii', 0.8409547222657274),
#  ('way', 0.840202439392257),
#  ('did', 0.8400282730619696),
#  ('military', 0.8399160078103303),
#  ('population', 0.8397909910070598),
#  ('using', 0.8395903534719682),
#  ('though', 0.8393132419796803),
#  ('small', 0.839300611855234),
#  ('following', 0.8385244969190742),
#  ('within', 0.8377240217815187),
#  ('non', 0.8374893869406888),
#  ('human', 0.837017047653756),
#  ('left', 0.837017047653756),
#  ('main', 0.8367793282873055),
#  ('among', 0.8365139717932784),
#  ('point', 0.8364474302022586),
#  ('r', 0.8354123195635494),
#  ('due', 0.8353036449525427),
#  ('p', 0.8345506338748675),
#  ('considered', 0.8343296294469105),
#  ('public', 0.8342049245963185),
#  ('popular', 0.8340799377143353),
#  ('computer', 0.8327716325973757),
#  ('west', 0.8326005549389265),
#  ('family', 0.8325291174564526),
#  ('east', 0.8324862110423552),
#  ('information', 0.8323429511265303),
#  ('important', 0.8323286049108816),
#  ('european', 0.8317951921349808),
#  ('man', 0.8313881271818498),
#  ('sometimes', 0.8311395340250531),
#  ('right', 0.8310955503995688),
#  ('old', 0.8304019553159961),
#  ('free', 0.8299996222631179),
#  ('word', 0.8299098254203015),
#  ('without', 0.8296546262151527),
#  ('last', 0.8295492098043654),
#  ('us', 0.8295190548655721),
#  ('members', 0.8292469382596122),
#  ('given', 0.8288057741058927),
#  ('times', 0.8284534434396374),
#  ('roman', 0.8266744176465252),
#  ('make', 0.8263884278579006),
#  ('h', 0.8256510842834204),
#  ('age', 0.8247734017117734),
#  ('place', 0.824691462685416),
#  ('l', 0.8246586548742718),
#  ('thus', 0.82426351894754),
#  ('science', 0.8241808622094893),
#  ('case', 0.8237658218845784),
#  ('become', 0.8234149072299406),
#  ('systems', 0.8233142602609425),
#  ('union', 0.823078746459708),
#  ('born', 0.8230450246918347),
#  ('york', 0.8229944058659198),
#  ('line', 0.8228761261372951),
#  ('countries', 0.8227914952978046),
#  ('does', 0.822621869045986),
#  ('isbn', 0.8225368730513847),
#  ('st', 0.8223835718621181),
#  ('control', 0.8221956631094447),
#  ('various', 0.8216283381853381),
#  ('others', 0.8215764934925373),
#  ('house', 0.8215246035666162),
#  ('article', 0.821281850559241),
#  ('island', 0.8209508100767334),
#  ('should', 0.8207583122359494),
#  ('led', 0.820670607730156),
#  ('back', 0.8206179231893523),
#  ('period', 0.8205124146554907),
#  ('player', 0.8204595905256342),
#  ('europe', 0.8204243485173501),
#  ('languages', 0.8203008378606084),
#  ('central', 0.8199998191979869),
#  ('water', 0.8191956446172461),
#  ('few', 0.8189793713875582),
#  ('western', 0.8189251817055743),
#  ('home', 0.8188709433283523),
#  ('began', 0.8188166561829189),
#  ('generally', 0.8183623569295262),
#  ('less', 0.8182710863127064),
#  ('k', 0.8181979706735835),
#  ('similar', 0.8176283161811604),
#  ('written', 0.8172021918914004),
#  ('original', 0.8170905369030139),
#  ('best', 0.8169413448202186),
#  ('must', 0.8168666117470177),
#  ('according', 0.816604323383908),
#  ('school', 0.8163786055426464),
#  ('france', 0.8152565752910335),
#  ('air', 0.8150450993206781),
#  ('single', 0.8150258382010551),
#  ('force', 0.8145423459188421),
#  ('v', 0.8142699286953987),
#  ('land', 0.8141332691405518),
#  ('groups', 0.8136624216961537),
#  ('down', 0.8136033138189165),
#  ('how', 0.8135835986899618),
#  ('works', 0.8135244157471584),
#  ('development', 0.8134651764008493),
#  ('official', 0.8134454174024781),
#  ('support', 0.8127698527454162),
#  ('england', 0.8118643332896218),
#  ('j', 0.8112737668823374),
#  ('rather', 0.8111303812175638),
#  ('data', 0.8107395380443664),
#  ('space', 0.8107395380443664),
#  ('greek', 0.8105535529410609),
#  ('km', 0.8104914359558213),
#  ('named', 0.8100131670246038),
#  ('germany', 0.8097621935559051),
#  ('just', 0.8095312586509392),
#  ('games', 0.8095102228409078),
#  ('said', 0.8085776905434942),
#  ('version', 0.8083424096676015),
#  ('late', 0.8083209774516741),
#  ('earth', 0.808020169474248),
#  ('company', 0.8078260434233324),
#  ('every', 0.8077828242714137),
#  ('economic', 0.8075445965947247),
#  ('short', 0.8075011872328541),
#  ('published', 0.8074360180792295),
#  ('black', 0.8074142803152136),
#  ('army', 0.8071746780151752),
#  ('off', 0.8070873279214605),
#  ('london', 0.806758704654337),
#  ('million', 0.8064725352386306),
#  ('body', 0.8064063154027281),
#  ('field', 0.8057180393372287),
#  ('christian', 0.8056063380914898),
#  ('either', 0.8052251077255899),
#  ('social', 0.8047057371992502),
#  ('empire', 0.8047057371992502),
#  ('o', 0.8045241103171203),
#  ('developed', 0.8038614395520004),
#  ('standard', 0.8038384684726398),
#  ('court', 0.8038154893205048),
#  ('service', 0.8036313649151922),
#  ('kingdom', 0.8035621844884961),
#  ('along', 0.8031919833299284),
#  ('college', 0.8030758655449308),
#  ('republic', 0.8029595419867595),
#  ('sea', 0.8025156250545924),
#  ('america', 0.8022807761489856),
#  ('today', 0.8021866017098038),
#  ('result', 0.8020686942079532),
#  ('held', 0.8017137026407513),
#  ('team', 0.8016662259736375),
#  ('light', 0.8015711702413523),
#  ('means', 0.8014044933285044),
#  ('never', 0.8004922886908385),
#  ('especially', 0.8004439290461314),
#  ('third', 0.8003471041636976),
#  ('further', 0.8002743929397382),
#  ('character', 0.8001773209500166),
#  ('forces', 0.8001773209500166),
#  ('take', 0.7999583904428826),
#  ('men', 0.7992972559569623),
#  ('society', 0.7990260192480945),
#  ('show', 0.7989518545438964),
#  ('open', 0.7989271147240211),
#  ('possible', 0.7986295227230762),
#  ('fact', 0.7984054595647483),
#  ('battle', 0.798205663142633),
#  ('took', 0.797678357935329),
#  ('former', 0.7975269384489488),
#  ('books', 0.79714689733079),
#  ('soviet', 0.7969688109205353),
#  ('river', 0.7969433316973592),
#  ('children', 0.7967902546546592),
#  ('having', 0.7964317242643791),
#  ('good', 0.7963803505662147),
#  ('local', 0.7963289379534945),
#  ('current', 0.79620023584773),
#  ('son', 0.79620023584773),
#  ('process', 0.7960454707849356),
#  ('natural', 0.7959938040255976),
#  ('present', 0.7953446386479511),
#  ('himself', 0.7952663216498608),
#  ('islands', 0.7948471071267433),
#  ('total', 0.7945310007869185),
#  ('near', 0.7940806717497566),
#  ('white', 0.7938677251279621),
#  ('days', 0.7937876996542756),
#  ('person', 0.7935738418831959),
#  ('itself', 0.7932518039992352),
#  ('seen', 0.7929282541987872),
#  ('culture', 0.7923311133067984),
#  ('little', 0.792221986191178),
#  ('above', 0.7915911492412961),
#  ('software', 0.7913427312129967),
#  ('largest', 0.7913150743411426),
#  ('words', 0.7912874064688753),
#  ('upon', 0.7912043367766186),
#  ('level', 0.7911766248296888),
#  ('father', 0.791037899394093),
#  ('created', 0.7909823317556675),
#  ('side', 0.7909823317556675),
#  ('red', 0.7908432184835319),
#  ('references', 0.7906200583437506),
#  ('press', 0.7905641566095665),
#  ('full', 0.7902558946808704),
#  ('region', 0.7900308472928301),
#  ('almost', 0.789776801038136),
#  ('image', 0.7896919138152289),
#  ('al', 0.7896919138152289),
#  ('famous', 0.7895218304180927),
#  ('play', 0.7893513336954556),
#  ('came', 0.7892374387607728),
#  ('role', 0.7890376773011759),
#  ('once', 0.7888946422839304),
#  ('certain', 0.7885789383573092),
#  ('league', 0.7882329134749715),
#  ('jewish', 0.7882040013188499),
#  ('james', 0.7879432579073264),
#  ('january', 0.7878561292004687),
#  ('site', 0.7875357359954909),
#  ('again', 0.7868611048959043),
#  ('numbers', 0.7867135937043908),
#  ('art', 0.7867135937043908),
#  ('member', 0.786417650164939),
#  ('areas', 0.7863583134920801),
#  ('movement', 0.7862394916327783),
#  ('religious', 0.7860310754597848),
#  ('type', 0.7860310754597848),
#  ('march', 0.7858818329749169),
#  ('community', 0.7858220484792593),
#  ('story', 0.785582408738263),
#  ('played', 0.7855523971779982),
#  ('production', 0.7854923362321848),
#  ('released', 0.7850402647849763),
#  ('center', 0.7848283176743299),
#  ('rights', 0.7847676461145945),
#  ('real', 0.7847372910825156),
#  ('related', 0.7844635165946772),
#  ('foreign', 0.7842192825407912),
#  ('low', 0.7840968537550776),
#  ('ancient', 0.7840662139839386),
#  ('terms', 0.7839435243228939),
#  ('view', 0.7839435243228939),
#  ('source', 0.7834506660247965),
#  ('act', 0.7834197502799071),
#  ('minister', 0.7831409114193536),
#  ('change', 0.7828298237704285),
#  ('energy', 0.7822350502821102),
#  ('produced', 0.7820146881515628),
#  ('research', 0.7818568764231908),
#  ('actor', 0.7818252729281208),
#  ('making', 0.7817303799651394),
#  ('civil', 0.7815719495022131),
#  ('december', 0.7815719495022131),
#  ('women', 0.7815402219908979),
#  ('special', 0.7815084806499372),
#  ('style', 0.7814131735486325),
#  ('william', 0.7813813767884887),
#  ('design', 0.7813813767884887),
#  ('japanese', 0.7813813767884887),
#  ('available', 0.7813177416181085),
#  ('chinese', 0.7811584102611734),
#  ('forms', 0.7811265021776417),
#  ('canada', 0.7810945801330145),
#  ('northern', 0.7809347601366453),
#  ('died', 0.7807745895808729),
#  ('class', 0.7805819203679831),
#  ('living', 0.7805175843221401),
#  ('next', 0.7803887422707279),
#  ('particular', 0.7803242360987598),
#  ('program', 0.7802919616897263),
#  ('council', 0.7802273701733198),
#  ('television', 0.780033253282987),
#  ('head', 0.7794151394877613),
#  ('david', 0.7791533176027071),
#  ('china', 0.7790548937625403),
#  ('middle', 0.7789892047150841),
#  ('established', 0.7788905611952048),
#  ('hand', 0.7787588308059173),
#  ('bc', 0.7787588308059173),
#  ('far', 0.7786268646926653),
#  ('july', 0.7779967848368986),
#  ('function', 0.777896805901336),
#  ('position', 0.7774955351241405),
#  ('y', 0.7772604537433319),
#  ('built', 0.7772268098270828),
#  ('george', 0.7771257865325669),
#  ('band', 0.7770246256770057),
#  ('together', 0.7769908747687184),
#  ('w', 0.7769233269479262),
#  ('latin', 0.7765507136135222),
#  ('thought', 0.7761079358417489),
#  ('eastern', 0.7760737668886071),
#  ('charles', 0.7757998509047214),
#  ('parts', 0.7757312147025639),
#  ('instead', 0.7754904906438326),
#  ('study', 0.7751106388605842),
#  ('might', 0.7749026326242209),
#  ('india', 0.7749026326242209),
#  ('code', 0.7748331688461823),
#  ('included', 0.773889068977376),
#  ('meaning', 0.773889068977376),
#  ('trade', 0.7736776515108783),
#  ('per', 0.7736423575771761),
#  ('june', 0.7732530313467736),
#  ('least', 0.7728973496086919),
#  ('half', 0.7725758008197106),
#  ('model', 0.7713122230388709),
#  ('economy', 0.7711299871529426),
#  ('prime', 0.7710934876689617),
#  ('traditional', 0.7710204362829209),
#  ('always', 0.770947314913113),
#  ('capital', 0.7708741234477247),
#  ('range', 0.7707275297817028),
#  ('november', 0.7705071107560629),
#  ('emperor', 0.7705071107560629),
#  ('young', 0.7701383287581874),
#  ('anti', 0.7699162043662939),
#  ('final', 0.769879120991787),
#  ('text', 0.7697306079856806),
#  ('players', 0.7693580638300848),
#  ('uk', 0.7690212235004165),
#  ('april', 0.7686452200340379),
#  ('run', 0.7684187346347541),
#  ('september', 0.7681157168206578),
#  ('addition', 0.7679257255694656),
#  ('radio', 0.7679257255694656),
#  ('live', 0.7677733958685014),
#  ('august', 0.767697118446792),
#  ('taken', 0.7676589515391898),
#  ('note', 0.7676589515391898),
#  ('italian', 0.7674295543645422),
#  ('lost', 0.7673529375133005),
#  ('nature', 0.7670457111496846),
#  ('project', 0.7668530754689952),
#  ('technology', 0.7666599611109207),
#  ('spanish', 0.7664275892303773),
#  ('october', 0.7663499775283619),
#  ('recent', 0.7660777260573455),
#  ('rate', 0.7660777260573455),
#  ('won', 0.7655695811588876),
#  ('true', 0.7646227025064238),
#  ('value', 0.7645829998330381),
#  ('uses', 0.7645432770621206),
#  ('russian', 0.764463771159825),
#  ('est', 0.7643841846636054),
#  ('wrote', 0.7634228104616154),
#  ('effect', 0.7633421637268583),
#  ('album', 0.7633018094190752),
#  ('southern', 0.7630997277715943),
#  ('africa', 0.7629376892627521),
#  ('whose', 0.7625718835078088),
#  ('top', 0.7625311338093208),
#  ('historical', 0.7619584259789882),
#  ('australia', 0.761794032607169),
#  ('catholic', 0.7615055228082429),
#  ('particularly', 0.7612573925411747),
#  ('self', 0.7611330366299074),
#  ('structure', 0.7610084861929898),
#  ('record', 0.7604665073583634),
#  ('evidence', 0.7602151165325116),
#  ('rule', 0.7600050184606033),
#  ('themselves', 0.7600050184606033),
#  ('influence', 0.7597099511899884),
#  ('cases', 0.759625446158781),
#  ('subject', 0.7590739817085903),
#  ('referred', 0.7590314039900833),
#  ('continued', 0.7587327265541328),
#  ('nations', 0.7586899676218617),
#  ('below', 0.7586043815108613),
#  ('rock', 0.7586043815108613),
#  ('japan', 0.758518704270013),
#  ('com', 0.7582181139393477),
#  ('song', 0.7581750807653733),
#  ('throughout', 0.7580458432469817),
#  ('names', 0.7580458432469817),
#  ('female', 0.7576568839156377),
#  ('title', 0.7576135503227863),
#  ('therefore', 0.7575701934760612),
#  ('our', 0.7575701934760612),
#  ('office', 0.757135341455702),
#  ('star', 0.7570917274374742),
#  ('paul', 0.7567857699778405),
#  ('too', 0.7566981409964268),
#  ('cities', 0.7566104172297388),
#  ('february', 0.7565225985067763),
#  ('independent', 0.7565225985067763),
#  ('author', 0.7564346846561073),
#  ('problem', 0.7563466755058661),
#  ('species', 0.7560820745325167),
#  ('education', 0.7559936824566066),
#  ('done', 0.7559936824566066),
#  ('philosophy', 0.7559494503675015),
#  ('come', 0.7558166096339238),
#  ('higher', 0.7557279285377132),
#  ('originally', 0.7556835517417321),
#  ('market', 0.7555058023924587),
#  ('town', 0.7554167821100232),
#  ('my', 0.7553722354895117),
#  ('season', 0.7551938052947378),
#  ('love', 0.7551491367066996),
#  ('strong', 0.7549702175280613),
#  ('israel', 0.7549254264149055),
#  ('irish', 0.7547460160148995),
#  ('writer', 0.7547460160148995),
#  ('films', 0.7545662110171514),
#  ('elements', 0.7543860099730638),
#  ('robert', 0.7543408976593347),
#  ('whether', 0.7542054114265837),
#  ('despite', 0.7540697007756401),
#  ('eventually', 0.7539791020253852),
#  ('here', 0.753752166364207),
#  ('football', 0.753706703826455),
#  ('action', 0.7532964046682518),
#  ('internet', 0.7532049482812986),
#  ('individual', 0.7530217299548614),
#  ('sound', 0.7530217299548614),
#  ('network', 0.752929967636984),
#  ('described', 0.7526540657840028),
#  ('practice', 0.7524696168887086),
#  ('characters', 0.7521458360006483),
#  ('re', 0.7516810799877786),
#  ('royal', 0.7516344604585943),
#  ('la', 0.7514944441703657),
#  ('events', 0.751026007268623),
#  ('formed', 0.7507436703878119),
#  ('commonly', 0.7504603708120612),
#  ('base', 0.7502235484856404),
#  ('received', 0.7501761030580087),
#  ('african', 0.749986050617481),
#  ('problems', 0.749986050617481),
#  ('food', 0.7497478739897965),
#  ('jews', 0.7496046408619709),
#  ('able', 0.749556841804718),
#  ('male', 0.7493653714723194),
#  ('typically', 0.7484013885736325),
#  ('mass', 0.7484013885736325),
#  ('complex', 0.7483043773452631),
#  ('lower', 0.7478176323099661),
#  ('includes', 0.7474752256788203),
#  ('outside', 0.7473771387555947),
#  ('legal', 0.7467862072786002),
#  ('complete', 0.7467367755958021),
#  ('significant', 0.7463899413198618),
#  ('parliament', 0.7463899413198618),
#  ('actually', 0.7463402771543646),
#  ('business', 0.7457920385835218),
#  ('fiction', 0.7456919764023523),
#  ('physical', 0.7456419009812512),
#  ('followed', 0.7455416613324264),
#  ('deaths', 0.7451898870219447),
#  ('key', 0.7450386793459065),
#  ('leader', 0.7449377245525406),
#  ('widely', 0.7449377245525406),
#  ('page', 0.7446848119713689),
#  ('basic', 0.7446341391142601),
#  ('types', 0.7445834360737752),
#  ('henry', 0.7433574295219989),
#  ('elected', 0.7433059620452),
#  ('beginning', 0.7433059620452),
#  ('fire', 0.7430997820617946),
#  ('building', 0.7426340546251122),
#  ('independence', 0.7425302152239234),
#  ('went', 0.742374220187027),
#  ('movie', 0.7421657850559953),
#  ('aircraft', 0.7421657850559953),
#  ('ever', 0.742113597176715),
#  ('canadian', 0.742009126278031),
#  ('material', 0.7417998030194802),
#  ('births', 0.7416949501432879),
#  ('video', 0.7416424757801552),
#  ('news', 0.741484860600744),
#  ('future', 0.7414322580690369),
#  ('scientific', 0.7413796234136456),
#  ('simply', 0.7412742576009277),
#  ('go', 0.7411159671349733),
#  ('defined', 0.7410102786092947),
#  ('laws', 0.7407454899485898),
#  ('get', 0.7405330732721918),
#  ('close', 0.7404798874713405),
#  ('industry', 0.7402134670002701),
#  ('specific', 0.7401066688321412),
#  ('examples', 0.740053220331593),
#  ('believe', 0.7385975285505761),
#  ('services', 0.7385975285505761),
#  ('idea', 0.738270707245881),
#  ('method', 0.7382161177588438),
#  ('introduced', 0.7382161177588438),
#  ('points', 0.738161494099983),
#  ('return', 0.7381068362336325),
#  ('cause', 0.7379426570321974),
#  ('indian', 0.7377781686743539),
#  ('britain', 0.7375033317565227),
#  ('features', 0.737282838926177),
#  ('majority', 0.7372276288465355),
#  ('size', 0.7372276288465355),
#  ('post', 0.7370617895298355),
#  ('lead', 0.737006439942764),
#  ('organization', 0.7369510553870153),
#  ('cannot', 0.736895635825753),
#  ('designed', 0.7363952784213099),
#  ('ireland', 0.7362836996981847),
#  ('cross', 0.736227857177643),
#  ('classical', 0.7361160656308473),
#  ('personal', 0.7360041318254447),
#  ('writing', 0.7359481114814349),
#  ('concept', 0.7357798362300363),
#  ('associated', 0.73555496796485),
#  ('required', 0.73555496796485),
#  ('soon', 0.735216586467456),
#  ('changes', 0.7348769026670638),
#  ('california', 0.7348201615005858),
#  ('located', 0.7348201615005858),
#  ('sense', 0.7345359081887268),
#  ('believed', 0.7338499533195704),
#  ('away', 0.7335049757973462),
#  ('started', 0.7335049757973462),
#  ('co', 0.7332164675130056),
#  ('religion', 0.7329849850117662),
#  ('mother', 0.7329270201755276),
#  ('county', 0.7327528989053795),
#  ('rules', 0.732694782757885),
#  ('studies', 0.732636628679694),
#  ('yet', 0.7325202065660466),
#  ('find', 0.7321700255824479),
#  ('knowledge', 0.7321115282628867),
#  ('put', 0.7320529925969992),
#  ('founded', 0.731700970977188),
#  ('policy', 0.7314655176374273),
#  ('currently', 0.7312885202663285),
#  ('provide', 0.7311111724438759),
#  ('working', 0.7310519784249847),
#  ('media', 0.7308148108113712),
#  ('election', 0.7307554208075182),
#  ('australian', 0.7303982533997386),
#  ('me', 0.7301593506088644),
#  ('thomas', 0.7300995256110356),
#  ('allowed', 0.7299198115919735),
#  ('russia', 0.729859827096307),
#  ('earlier', 0.7297397381048658),
#  ('greater', 0.7297397381048658),
#  ('limited', 0.7296796335201363),
#  ('object', 0.729378507921057),
#  ('brought', 0.729257775596479),
#  ('online', 0.7289552364201755),
#  ('association', 0.7286516807605006),
#  ('lord', 0.7286516807605006),
#  ('mostly', 0.7284081005326025),
#  ('blue', 0.7281638631635807),
#  ('constitution', 0.7281027007965482),
#  ('across', 0.7281027007965482),
#  ('added', 0.7278576378362978),
#  ('interest', 0.7277962684901205),
#  ('things', 0.7277348576080058),
#  ('relations', 0.7276734051430789),
#  ('speed', 0.727118453961007),
#  ('federal', 0.7267465961286617),
#  ('singer', 0.7264355506052274),
#  ('effects', 0.7263732139405479),
#  ('growth', 0.7263108346427902),
#  ('sources', 0.7262484126633362),
#  ('your', 0.7260608901474512),
#  ('remains', 0.7256846861113899),
#  ('z', 0.7256218346238223),
#  ('probably', 0.725369995961007),
#  ('gave', 0.725369995961007),
#  ('simple', 0.7253069278687669),
#  ('attack', 0.7251806612235645),
#  ('longer', 0.7251174625706015),
#  ('reference', 0.72492760468857),
#  ('saint', 0.7247373528650335),
#  ('success', 0.7244830686102215),
#  ('killed', 0.7244193873586164),
#  ('past', 0.7243556619299368),
#  ('career', 0.7243556619299368),
#  ('need', 0.7241642200700233),
#  ('park', 0.7239723787718146),
#  ('definition', 0.7233944443037846),
#  ('say', 0.72287766560814),
#  ('etc', 0.7227480177253087),
#  ('give', 0.7224881751356858),
#  ('peace', 0.7224881751356858),
#  ('chief', 0.7222928130383716),
#  ('stories', 0.7221623421892842),
#  ('security', 0.7220316872759678),
#  ('wide', 0.7219662906599063),
#  ('ball', 0.721900847865228),
#  ('saw', 0.7215729393064052),
#  ('machine', 0.7214414507225969),
#  ('better', 0.7213756365340169),
#  ('cell', 0.7213097756742233),
#  ('leading', 0.7212438680880291),
#  ('becomes', 0.7210458644178073),
#  ('spain', 0.7209136273231166),
#  ('larger', 0.7209136273231166),
#  ('products', 0.7208474382144718),
#  ('parties', 0.7208474382144718),
#  ('night', 0.7208474382144718),
#  ('remained', 0.7206485879730958),
#  ('prize', 0.7205157848222488),
#  ('months', 0.7204493121812381),
#  ('website', 0.7204493121812381),
#  ('big', 0.7204493121812381),
#  ('cultural', 0.7203827920880137),
#  ('money', 0.7203827920880137),
#  ('help', 0.7202496093188938),
#  ('territory', 0.7202496093188938),
#  ('private', 0.7201829465297476),
#  ('moved', 0.7201829465297476),
#  ('letter', 0.7198489162646198),
#  ('wife', 0.7198489162646198),
#  ('politics', 0.7196479229944253),
#  ('lines', 0.7196479229944253),
#  ('largely', 0.719580829041806),
#  ('contains', 0.7193792577894984),
#  ('companies', 0.7192446352141315),
#  ('lake', 0.7189748077950195),
#  ('perhaps', 0.7189072292940536),
#  ('green', 0.7185686039806842),
#  ('already', 0.7182968208212405),
#  ('dead', 0.7182287519114204),
#  ('iii', 0.7182287519114204),
#  ('library', 0.7181606336345668),
#  ('separate', 0.7180924659309783),
#  ('refer', 0.7180242487408524),
#  ('makes', 0.7179559820042852),
#  ('appeared', 0.7178876656612715),
#  ('dutch', 0.717613903021076),
#  ('holy', 0.7175453377421782),
#  ('era', 0.7174080572177872),
#  ('novel', 0.7172017606023218),
#  ('successful', 0.7170639782607015),
#  ('italy', 0.7169259943355328),
#  ('letters', 0.716856926625425),
#  ('results', 0.7167878083347885),
#  ('matter', 0.7165801493615147),
#  ('produce', 0.7163720329335403),
#  ('origin', 0.716302558843811),
#  ('claim', 0.7161634573688402),
#  ('whole', 0.7158148065278724),
#  ('directly', 0.7157449220577463),
#  ('attempt', 0.7157449220577463),
#  ('actress', 0.7156049983092072),
#  ('surface', 0.7155349589037145),
#  ('revolution', 0.7154648677258377),
#  ('highly', 0.715254282919209),
#  ('caused', 0.7151839840125507),
#  ('status', 0.7151136330133334),
#  ('musical', 0.7149727744796406),
#  ('richard', 0.7149022668160956),
#  ('commercial', 0.7148317068018526),
#  ('division', 0.7146904294619013),
#  ('color', 0.7146197120062265),
#  ('health', 0.7143363154239868),
#  ('coast', 0.7143363154239868),
#  ('release', 0.7143363154239868),
#  ('latter', 0.7142653342613616),
#  ('authority', 0.7140520728814514),
#  ('treaty', 0.7139096330583619),
#  ('turn', 0.7137669801614683),
#  ('michael', 0.7134094122271284),
#  ('nation', 0.7130505008932861),
#  ('direct', 0.7129785566777626),
#  ('asia', 0.7128345057561105),
#  ('edition', 0.7126902377267917),
#  ('programming', 0.7126180221262362),
#  ('playing', 0.7120383302050858),
#  ('date', 0.7119656217908996),
#  ('mary', 0.7117471656516394),
#  ('native', 0.7117471656516394),
#  ('whom', 0.7117471656516394),
#  ('married', 0.7114551160991723),
#  ('towards', 0.7113087580456825),
#  ('issues', 0.7110153725614796),
#  ('double', 0.710941886323181),
#  ('primary', 0.7104259081500032),
#  ('basis', 0.7104259081500032),
#  ('allow', 0.7103519711918598),
#  ('enough', 0.7103519711918598),
#  ('memory', 0.7102779775698049),
#  ('reason', 0.7100556559953857),
#  ('web', 0.7099071569618319),
#  ('exist', 0.709758429526766),
#  ('provided', 0.7096094731040922),
#  ('oil', 0.7093856078310424),
#  ('course', 0.7093856078310424),
#  ('functions', 0.7093856078310424),
#  ('alexander', 0.7093108709409889),
#  ('analysis', 0.7093108709409889),
#  ('chemical', 0.7093108709409889),
#  ('mid', 0.7090863138359986),
#  ('replaced', 0.7090863138359986),
#  ('queen', 0.709011345741425),
#  ('claims', 0.7088612355151611),
#  ('tv', 0.7088612355151611),
#  ('sun', 0.7088612355151611),
#  ('literature', 0.7087108927401087),
#  ('metal', 0.7086356339590416),
#  ('amount', 0.7085603168152113),
#  ('divided', 0.7082584631007582),
#  ('blood', 0.7080314562940865),
#  ('likely', 0.7079556695196223),
#  ('access', 0.7078039187530916),
#  ('average', 0.7078039187530916),
#  ('length', 0.7076519311842978),
#  ('smaller', 0.7075758484064799),
#  ('medical', 0.7074235044776287),
#  ('property', 0.7073472431716229),
#  ('students', 0.7071945414879586),
#  ('degree', 0.7071181009544774),
#  ('elections', 0.7070416005224438),
#  ('club', 0.7069650401135901),
#  ('claimed', 0.7068884196495047),
#  ('performance', 0.7068117390516329),
#  ('director', 0.7065044137461379),
#  ('digital', 0.7063503882376327),
#  ('front', 0.7062732844915851),
#  ('museum', 0.7062732844915851),
#  ('difficult', 0.7061961199781013),
#  ('tradition', 0.7061961199781013),
#  ('nearly', 0.7061188946173191),
#  ('schools', 0.7059642610336735),
#  ('washington', 0.7058868526503483),
#  ('gas', 0.7057318522984296),
#  ('jesus', 0.7056542601684848),
#  ('map', 0.7056542601684848),
#  ('louis', 0.7055766066280673),
#  ('rome', 0.7055766066280673),
#  ('unit', 0.7053432767327441),
#  ('baseball', 0.7051874149269399),
#  ('mind', 0.70503130552491),
#  ('peter', 0.7049531577703332),
#  ('mark', 0.7049531577703332),
#  ('collection', 0.7046399444738256),
#  ('product', 0.7044829633011552),
#  ('congress', 0.7044043787932647),
#  ('programs', 0.7037734375818885),
#  ('changed', 0.7036942855263896),
#  ('ideas', 0.703615069988422),
#  ('moon', 0.7034564481253078),
#  ('entire', 0.7032975713114054),
#  ('user', 0.7032180370843533),
#  ('ground', 0.703138438863017),
#  ('records', 0.7029790500938757),
#  ('frequently', 0.7028992593738584),
#  ('increase', 0.7028194043151321),
#  ('highest', 0.702739484831185),
#  ('sent', 0.7026595008353426),
#  ('finally', 0.7026595008353426),
#  ('board', 0.7025794522407669),
#  ('don', 0.7024993389604562),
#  ('notable', 0.7023389179938023),
#  ('read', 0.7021782372360779),
#  ('methods', 0.7021782372360779),
#  ('recently', 0.7020977992163089),
#  ('bit', 0.7019367274549949),
#  ('involved', 0.7014519400283106),
#  ('variety', 0.7014519400283106),
#  ('call', 0.7013709119198919),
#  ('democratic', 0.701289817800792),
#  ('ten', 0.7012086575813352),
#  ('served', 0.7008833539004287),
#  ('minor', 0.7003934000157901),
#  ('hard', 0.7002295462436376),
#  ('birth', 0.6998187327663079),
#  ('objects', 0.6998187327663079),
#  ('nuclear', 0.6994888631423437),
#  ('increased', 0.6994888631423437),
#  ('section', 0.6989920133070371),
#  ('street', 0.6989089651645566),
#  ('windows', 0.6988258482451444),
#  ('relatively', 0.6987426624538178),
#  ('car', 0.6986594076954104),
#  ('move', 0.6985760838745714),
#  ('create', 0.6984926908957659),
#  ('returned', 0.6984926908957659),
#  ('bank', 0.6984092286632734),
#  ('conditions', 0.6983256970811877),
#  ('operation', 0.6980746852755202),
#  ('adopted', 0.6979908753322753),
#  ('relationship', 0.6979908753322753),
#  ('christ', 0.6979069955571078),
#  ('hall', 0.6976549362688316),
#  ('appear', 0.6974022449888422),
#  ('rest', 0.6970643356093962),
#  ('child', 0.6969796812373678),
#  ('element', 0.696810159367457),
#  ('appears', 0.6967252916707263),
#  ('takes', 0.6964702603362436),
#  ('fall', 0.6964702603362436),
#  ...]

# %%
len(vocab_to_int), len(int_to_vocab)
# Out:
# (36074, 36074)

# %%
train_words = list()

for i in int_words:   
    if prob_words[int_to_vocab[i]] < np.random.random():
        train_words.append(i)

# %%
len(int_words), len(train_words)
# Out:
# (16426833, 4350952)

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    
    ''' Get a list of words in a window around an index. '''
    
    rand = np.random.randint(1, window_size)
    
    return words[max(0,idx-rand):idx]+words[idx+1:idx+rand+1]

# %%
lis = ['a','b','c','d','e','f','g','h','i']

get_target(lis, 1, 5)
# Out:
# ['a', 'c', 'd', 'e', 'f']

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()

with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='input')
    labels = tf.placeholder(tf.int32, [None, None], name='output')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(vocab_to_int)
n_embedding =  200

with train_graph.as_default():
    embedding = tf.Variable(tf.random.uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample

n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random

with train_graph.as_default():
    
    valid_size = 16
    valid_window = 100
    
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, random.sample(range(1000,1000+valid_window), valid_size//2))
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# !mkdir checkpoints
# Out:
# mkdir: checkpoints: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10
loss_list = list()

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs), "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100), "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
                loss_list.append(loss/100)
            
            if iteration % 1000 == 0:

                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.2725 0.3679 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.1863 0.3668 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.1613 0.3855 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.1863 0.3407 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.1087 0.3399 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.1454 0.3181 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.1747 0.3065 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.1547 0.3034 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.0893 0.3081 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.1237 0.3127 sec/batch
# Nearest to as: serving, neuroscience, autobiographical, nations, dressage, argon, food, ate,
# Nearest to its: agonists, parsons, proceed, nitrogen, correlations, biscuit, khmer, philosophic,
# Nearest to see: regrets, nullify, felis, bao, undoubtedly, stilgar, neburg, angelic,
# Nearest to which: speculated, superset, stump, agricultural, harris, launched, diz, phased,
# Nearest to who: duluth, neg, archaic, coptic, strait, domino, ditka, du,
# Nearest to use: grozny, otters, veeck, preacher, scant, esther, arrives, khalifa,
# Nearest to years: plasmid, gardeners, facts, pitch, neg, parkland, familiar, dismissal,
# Nearest to most: mammoths, shipment, precision, orr, lisbon, eddy, human, intimacy,
# Nearest to consists: operation, featured, divinity, discharges, exhibition, peach, electrolytes, chopped,
# Nearest to discovered: residues, delicate, pym, audiences, emulsion, jackets, citation, colony,
# Nearest to experience: deva, wagon, residency, esperantists, leeds, bits, marginal, hapless,
# Nearest to applications: nilsson, incitement, horsemen, chekhov, dad, latvia, khalil, albinus,
# Nearest to san: mass, penguins, pressed, tarsus, yet, locke, sermon, leaning,
# Nearest to question: berry, wavy, gratis, devalued, sadc, illumination, simplicity, huston,
# Nearest to institute: emphasising, also, potassium, hesitation, fijians, nitro, hyena, voted,
# Nearest to existence: shepherd, nippur, universities, involution, baez, afforded, wide, may,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.0864 0.3128 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.0425 0.3144 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 4.9822 0.3107 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 4.9411 0.3079 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 4.9154 0.3110 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.8850 0.3059 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.8819 0.3112 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.8237 0.3149 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.8257 0.3075 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.7796 0.3218 sec/batch
# Nearest to as: serving, nations, food, devolved, autobiographical, various, neuroscience, emotion,
# Nearest to its: proceed, nazi, agonists, personal, parsons, intrinsically, sealand, asthma,
# Nearest to see: regrets, pick, felis, celebrating, angelic, bao, nullify, choral,
# Nearest to which: speculated, agricultural, superset, stump, harris, ethnic, launched, remaining,
# Nearest to who: duluth, strait, archaic, neg, deep, called, domino, ditka,
# Nearest to use: lead, would, preacher, veeck, risk, naming, villain, trusted,
# Nearest to years: plasmid, facts, pitch, gardeners, familiar, four, neg, rbis,
# Nearest to most: shipment, mammoths, precision, human, it, professional, lisbon, idea,
# Nearest to consists: operation, featured, divinity, exhibition, struck, peach, netherlands, discharges,
# Nearest to discovered: residues, delicate, audiences, pym, citation, colony, focus, jackets,
# Nearest to experience: bits, interpreted, declining, simple, stated, hopes, deva, wagon,
# Nearest to applications: nilsson, horsemen, mortality, dad, key, restoring, latvia, incitement,
# Nearest to san: mass, yet, pressed, northwest, penguins, leaning, unusual, reform,
# Nearest to question: berry, gratis, simplicity, modern, wavy, sadc, hispanic, illumination,
# Nearest to institute: also, emphasising, potassium, hesitation, voted, nitro, rigorous, statewide,
# Nearest to existence: may, nippur, wide, th, shepherd, involution, think, doc,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.7654 0.3763 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.7639 0.4058 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.7139 0.3988 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.6633 0.3682 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7066 0.3604 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.6664 0.3903 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.6639 0.3869 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.6484 0.3768 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.6912 0.3450 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.6365 0.3609 sec/batch
# Nearest to as: serving, nations, devolved, neuroscience, autobiographical, pierced, separation, food,
# Nearest to its: proceed, nazi, nitrogen, agonists, sectors, projects, correlations, sealand,
# Nearest to see: undoubtedly, regrets, celebrating, angelic, nullify, felis, pick, neburg,
# Nearest to which: speculated, agricultural, superset, ethnic, stump, harris, diz, phased,
# Nearest to who: duluth, strait, archaic, thriving, ditka, juvenile, called, neg,
# Nearest to use: lead, villain, risk, veeck, preacher, would, webber, hamsun,
# Nearest to years: facts, plasmid, pitch, four, gardeners, chatham, macro, brushes,
# Nearest to most: mammoths, shipment, human, precision, hd, recreational, lisbon, eddy,
# Nearest to consists: operation, featured, divinity, trap, discharges, gig, chopped, struck,
# Nearest to discovered: residues, delicate, pym, colony, audiences, citation, emulsion, outspoken,
# Nearest to experience: interpreted, bits, declining, wagon, her, hopes, leeds, esperantists,
# Nearest to applications: incitement, nilsson, horsemen, dad, mortality, key, khalil, restoring,
# Nearest to san: mass, pressed, yet, offline, tarsus, sermon, penguins, northwest,
# Nearest to question: berry, gratis, simplicity, illumination, wavy, devalued, modern, sadc,
# Nearest to institute: also, emphasising, voted, potassium, statewide, hesitation, pardon, rigorous,
# Nearest to existence: may, nippur, doc, shepherd, universities, involution, wide, incompatibility,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.6258 0.3856 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.6018 0.4200 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.6122 0.3510 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.5864 0.3160 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.6126 0.3254 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.5729 0.3209 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.5784 0.3628 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.5701 0.3474 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.5523 0.3386 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.5190 0.3469 sec/batch
# Nearest to as: serving, devolved, nations, neuroscience, food, autobiographical, draught, pierced,
# Nearest to its: proceed, nitrogen, correlations, sectors, sealand, largely, biscuit, intrinsically,
# Nearest to see: celebrating, nullify, undoubtedly, regrets, angelic, felis, bao, punctuation,
# Nearest to which: agricultural, superset, speculated, stump, ethnic, schwa, harris, certificate,
# Nearest to who: duluth, strait, brother, archaic, juvenile, ditka, coptic, thriving,
# Nearest to use: risk, veeck, lead, barbaric, enables, aggravated, naming, hamsun,
# Nearest to years: four, facts, plasmid, pitch, population, gardeners, female, brushes,
# Nearest to most: mammoths, shipment, human, precision, hd, lisbon, typewriters, computable,
# Nearest to consists: operation, divinity, featured, gig, discharges, trap, requested, chopped,
# Nearest to discovered: residues, delicate, pym, colony, emulsion, audiences, jackets, mosaics,
# Nearest to experience: marginal, wagon, deva, esperantists, leeds, interpreted, residency, hopes,
# Nearest to applications: incitement, horsemen, extinguish, dad, nilsson, chekhov, resistor, key,
# Nearest to san: offline, pressed, palaeologus, tarsus, northwest, leaning, conclave, sermon,
# Nearest to question: illumination, simplicity, berry, gratis, wavy, devalued, huston, sadc,
# Nearest to institute: also, emphasising, statewide, voted, hesitation, nitro, potassium, incumbent,
# Nearest to existence: may, doc, shepherd, nippur, involution, baez, incompatibility, lengths,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.5518 0.3695 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.5170 0.3137 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.5186 0.3185 sec/batch
# Epoch 2/10 Iteration: 4400 Avg. Training loss: 4.5193 0.1640 sec/batch
# Epoch 2/10 Iteration: 4500 Avg. Training loss: 4.4786 0.3200 sec/batch
# Epoch 2/10 Iteration: 4600 Avg. Training loss: 4.4202 0.3175 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.4145 0.3178 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.3905 0.3101 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.4173 0.3127 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.3722 0.3128 sec/batch
# Nearest to as: neuroscience, serving, devolved, food, nations, draught, separation, autobiographical,
# Nearest to its: proceed, sealand, sectors, largely, nitrogen, biscuit, invulnerable, intrinsically,
# Nearest to see: nullify, celebrating, undoubtedly, felis, angelic, bao, castile, regrets,
# Nearest to which: speculated, agricultural, superset, ethnic, stump, gendarmerie, alms, schwa,
# Nearest to who: brother, duluth, coptic, archaic, strait, ditka, juvenile, consented,
# Nearest to use: risk, aac, veeck, enables, mandriva, lead, incoming, colliding,
# Nearest to years: four, facts, plasmid, bonewits, brushes, population, gardeners, pitch,
# Nearest to most: mammoths, shipment, human, typewriters, precision, computable, hd, intelligibility,
# Nearest to consists: operation, discharges, featured, trap, divinity, chopped, gig, requested,
# Nearest to discovered: residues, delicate, colony, pym, emulsion, misquoted, audiences, mosaics,
# Nearest to experience: marginal, deva, interpreted, wagon, versus, downwards, declining, peaking,
# Nearest to applications: extinguish, incitement, function, key, polymer, resistor, signals, mozilla,
# Nearest to san: offline, palaeologus, conclave, northwest, leaning, tarsus, conservatory, town,
# Nearest to question: illumination, simplicity, wavy, berry, huston, gratis, wwf, sadc,
# Nearest to institute: also, emphasising, statewide, voted, hesitation, scandals, pardon, lublin,
# Nearest to existence: may, involution, porta, doc, nippur, incompatibility, might, shepherd,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4285 0.3125 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4218 0.3129 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.3893 0.3123 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.3538 0.3080 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.3374 0.3104 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.3444 0.3100 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.3372 0.3164 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3276 0.3089 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.3477 0.3063 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.3115 0.3160 sec/batch
# Nearest to as: serving, neuroscience, devolved, nations, tleilax, autobiographical, various, separation,
# Nearest to its: proceed, sealand, sectors, largely, nitrogen, khmer, biscuit, invulnerable,
# Nearest to see: nullify, celebrating, punctuation, undoubtedly, angelic, felis, mirage, etymologies,
# Nearest to which: agricultural, speculated, superset, ethnic, stump, schwa, valhalla, exposed,
# Nearest to who: brother, ditka, juvenile, duluth, coptic, consented, strait, father,
# Nearest to use: risk, enables, aac, lead, speed, hydrophilic, mandriva, hen,
# Nearest to years: four, plasmid, bonewits, facts, brushes, population, pitch, gardeners,
# Nearest to most: mammoths, human, shipment, shulkhan, it, intelligibility, precision, typewriters,
# Nearest to consists: operation, trap, discharges, chopped, gig, isolated, requested, divinity,
# Nearest to discovered: residues, delicate, emulsion, colony, pym, misquoted, mosaics, norodom,
# Nearest to experience: marginal, interpreted, deva, wagon, deny, zombies, peaking, stated,
# Nearest to applications: polymer, key, incitement, function, embed, resistor, signals, mozilla,
# Nearest to san: palaeologus, northwest, offline, conclave, leaning, puppet, reinhard, town,
# Nearest to question: illumination, simplicity, sadc, wavy, wwf, gratis, huston, np,
# Nearest to institute: also, statewide, lublin, scandals, emphasising, hesitation, voted, pardon,
# Nearest to existence: may, porta, argue, comets, involution, nippur, doc, might,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.2970 0.3133 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.3435 0.3058 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.2701 0.3100 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.2879 0.3112 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3280 0.3059 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.2905 0.3115 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.2764 0.3135 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3207 0.3159 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.2477 0.3060 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.2877 0.3065 sec/batch
# Nearest to as: serving, neuroscience, complex, separation, pertain, nations, particulate, pierced,
# Nearest to its: sealand, proceed, sectors, biscuit, correlations, largely, khmer, invulnerable,
# Nearest to see: nullify, celebrating, punctuation, reference, undoubtedly, etymologies, baptismal, felis,
# Nearest to which: speculated, agricultural, superset, valhalla, stump, schwa, ethnic, pharaoh,
# Nearest to who: brother, ditka, juvenile, consented, duluth, advised, archaic, agar,
# Nearest to use: risk, enables, lead, hydrophilic, hen, veeck, aac, mandriva,
# Nearest to years: four, population, bonewits, female, plasmid, facts, mortality, brushes,
# Nearest to most: mammoths, human, shipment, it, shulkhan, computable, intelligibility, precision,
# Nearest to consists: operation, discharges, trap, quetta, peach, isolated, steered, gig,
# Nearest to discovered: residues, delicate, emulsion, misquoted, colony, pym, mosaics, backstage,
# Nearest to experience: deva, interpreted, marginal, themes, wagon, deny, precursors, zombies,
# Nearest to applications: polymer, resistor, mozilla, incitement, function, key, signals, extinguish,
# Nearest to san: palaeologus, offline, northwest, conclave, lecturer, impressionists, conservatory, nhl,
# Nearest to question: illumination, simplicity, wwf, wavy, sadc, pitfalls, doctrine, supervises,
# Nearest to institute: also, statewide, lublin, emphasising, scandals, voted, hesitation, accommodated,
# Nearest to existence: argue, may, comets, porta, involution, constructions, god, self,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.2981 0.3189 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.2768 0.3105 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.2893 0.3088 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.2435 0.3153 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.2273 0.3079 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.2511 0.3103 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.1815 0.3086 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.2799 0.3156 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.2742 0.3198 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.2804 0.3113 sec/batch
# Nearest to as: serving, nations, performers, pertain, devolved, cogent, competent, gibraltarians,
# Nearest to its: sealand, sectors, proceed, largely, legislatures, biscuit, correlations, khmer,
# Nearest to see: nullify, celebrating, punctuation, undoubtedly, redirects, reference, etymologies, hogmanay,
# Nearest to which: speculated, superset, agricultural, valhalla, ethnic, schwa, sweetheart, blossoms,
# Nearest to who: brother, ditka, consented, juvenile, advised, duluth, called, archaic,
# Nearest to use: risk, enables, hydrophilic, manama, mandriva, veeck, hen, aac,
# Nearest to years: four, bonewits, population, female, facts, plasmid, brushes, mortality,
# Nearest to most: mammoths, shipment, human, oddities, intelligibility, it, lisbon, precision,
# Nearest to consists: discharges, operation, trap, peach, quetta, netherlands, steered, isolated,
# Nearest to discovered: residues, delicate, misquoted, emulsion, mosaics, colony, pym, settled,
# Nearest to experience: deva, themes, marginal, intelligent, wagon, precursors, deny, interpreted,
# Nearest to applications: mozilla, resistor, polymer, microsoft, embed, protocols, databases, incitement,
# Nearest to san: palaeologus, conclave, offline, conservatory, northwest, impressionists, reinhard, lecturer,
# Nearest to question: illumination, simplicity, wwf, pitfalls, supervises, sadc, overt, subtlety,
# Nearest to institute: also, statewide, lublin, scandals, nebula, emphasising, voted, pardon,
# Nearest to existence: argue, comets, porta, involution, constructions, may, evidenced, entails,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.1779 0.3136 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.1996 0.3062 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.2203 0.3012 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.1536 0.3526 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.1834 0.3150 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.1851 0.3124 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2278 0.3599 sec/batch
# Epoch 3/10 Iteration: 8800 Avg. Training loss: 4.1849 0.3307 sec/batch
# Epoch 3/10 Iteration: 8900 Avg. Training loss: 4.1359 0.3518 sec/batch
# Epoch 3/10 Iteration: 9000 Avg. Training loss: 4.1400 0.3405 sec/batch
# Nearest to as: serving, neuroscience, nations, gibraltarians, performers, algae, tleilax, pertain,
# Nearest to its: sealand, sectors, largely, nitrogen, bg, legislatures, khmer, aquaria,
# Nearest to see: nullify, celebrating, punctuation, reference, redirects, etymologies, undoubtedly, bao,
# Nearest to which: speculated, agricultural, superset, valhalla, ethnic, blossoms, literate, perhaps,
# Nearest to who: brother, consented, ditka, juvenile, father, advised, archaic, duluth,
# Nearest to use: risk, hydrophilic, mandriva, aac, enables, hen, veeck, hamsun,
# Nearest to years: four, bonewits, female, population, mortality, facts, plasmid, brushes,
# Nearest to most: mammoths, shipment, oddities, precision, innovations, shulkhan, impart, intelligibility,
# Nearest to consists: operation, discharges, trap, quetta, isolated, peach, steered, brigades,
# Nearest to discovered: residues, delicate, emulsion, misquoted, colony, mosaics, settled, comet,
# Nearest to experience: deva, themes, versus, intelligent, wagon, marginal, neighborhoods, precursors,
# Nearest to applications: mozilla, resistor, polymer, microsoft, embed, extinguish, tutorials, applets,
# Nearest to san: palaeologus, conclave, unusual, conservatory, northwest, offline, penguins, lecturer,
# Nearest to question: illumination, simplicity, wwf, pitfalls, overt, doctrine, supervises, subtlety,
# Nearest to institute: also, statewide, lublin, medical, scandals, rigorous, pardon, nebula,
# Nearest to existence: god, lengths, argue, comets, may, indeed, evidenced, entails,
# Epoch 3/10 Iteration: 9100 Avg. Training loss: 4.1431 0.3856 sec/batch
# Epoch 3/10 Iteration: 9200 Avg. Training loss: 4.0985 0.3716 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.1316 0.3502 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.1004 0.3470 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.1652 0.3499 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1101 0.3580 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1652 0.3862 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.0504 0.3957 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.0964 0.3365 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.0679 0.3291 sec/batch
# Nearest to as: serving, nations, particulate, algae, neuroscience, various, pelvic, compare,
# Nearest to its: sealand, bg, largely, encompassing, sectors, khmer, nitrogen, aquaria,
# Nearest to see: nullify, celebrating, punctuation, etymologies, reference, redirects, distributive, baptismal,
# Nearest to which: speculated, agricultural, superset, valhalla, schwa, perhaps, blossoms, comprise,
# Nearest to who: brother, consented, agar, ditka, duluth, juvenile, crimson, advised,
# Nearest to use: hen, hydrophilic, risk, aac, mandriva, manama, marijuana, hamsun,
# Nearest to years: four, bonewits, female, population, mortality, plasmid, year, live,
# Nearest to most: oddities, mammoths, precision, shooters, innovations, hd, shulkhan, it,
# Nearest to consists: discharges, operation, quetta, the, trap, isosceles, isolated, steered,
# Nearest to discovered: residues, delicate, colony, emulsion, misquoted, comet, mosaics, cassini,
# Nearest to experience: intelligent, versus, marginal, deva, wagon, dosage, precursors, tails,
# Nearest to applications: resistor, mozilla, polymer, embed, extinguish, microsoft, tutorials, applets,
# Nearest to san: palaeologus, unusual, conclave, santa, conservatory, ave, angeles, northwest,
# Nearest to question: illumination, simplicity, wwf, supervises, np, sadc, pitfalls, syllogism,
# Nearest to institute: statewide, also, colleges, medical, lublin, scandals, university, school,
# Nearest to existence: lengths, argue, entails, involution, reformers, god, may, evidenced,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.0720 0.3503 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.0972 0.3475 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.0922 0.3427 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.0936 0.3391 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1346 0.3721 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1088 0.4082 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.0647 0.3389 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1049 0.4113 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1138 0.3616 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1183 0.3442 sec/batch
# Nearest to as: serving, performers, nations, algae, particulate, complex, compare, various,
# Nearest to its: sealand, encompassing, khmer, largely, bg, biscuit, sectors, aquaria,
# Nearest to see: nullify, celebrating, punctuation, redirects, distributive, hogmanay, etymologies, baptismal,
# Nearest to which: agricultural, speculated, valhalla, superset, blossoms, perhaps, comprise, regimental,
# Nearest to who: brother, consented, agar, crimson, called, ditka, juvenile, duluth,
# Nearest to use: mandriva, aac, manama, hydrophilic, fallacies, risk, discount, hen,
# Nearest to years: four, bonewits, female, population, mortality, plasmid, year, live,
# Nearest to most: oddities, mammoths, hd, precision, computable, it, human, shulkhan,
# Nearest to consists: discharges, quetta, the, operation, isosceles, isolated, peach, trap,
# Nearest to discovered: residues, delicate, colony, emulsion, misquoted, comet, mosaics, cassini,
# Nearest to experience: intelligent, versus, marginal, dosage, themes, wagon, precursors, peaking,
# Nearest to applications: resistor, mozilla, polymer, embed, databases, tutorials, microsoft, applets,
# Nearest to san: palaeologus, ave, conclave, santa, unusual, angeles, impressionists, opted,
# Nearest to question: illumination, simplicity, wwf, supervises, pitfalls, sadc, syllogism, np,
# Nearest to institute: also, statewide, colleges, medical, scandals, lublin, school, university,
# Nearest to existence: lengths, entails, wide, indeed, evidenced, constructions, may, involution,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.0737 0.3965 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.0531 0.3357 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.0736 0.3547 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1289 0.3545 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.0984 0.3480 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.0985 0.3454 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.0657 0.3532 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.0592 0.3422 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.0534 0.3471 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1037 0.3540 sec/batch
# Nearest to as: nations, serving, various, algae, immensely, compare, performers, pertain,
# Nearest to its: sealand, encompassing, largely, legislatures, khmer, sectors, privileged, biscuit,
# Nearest to see: nullify, celebrating, punctuation, redirects, article, etymologies, external, baptismal,
# Nearest to which: agricultural, speculated, valhalla, superset, perhaps, secession, writeups, blossoms,
# Nearest to who: brother, consented, agar, continue, advised, crimson, called, charting,
# Nearest to use: manama, mandriva, risk, discount, aac, hen, hydrophilic, marijuana,
# Nearest to years: four, bonewits, population, female, mortality, year, live, plasmid,
# Nearest to most: oddities, mammoths, preserved, innovations, shooters, adherence, precision, human,
# Nearest to consists: the, discharges, quetta, isosceles, reciprocity, peach, isolated, form,
# Nearest to discovered: residues, colony, delicate, misquoted, mosaics, emulsion, cassini, settled,
# Nearest to experience: intelligent, versus, marginal, neighborhoods, themes, peaking, precursors, wagon,
# Nearest to applications: resistor, mozilla, polymer, embed, microsoft, applets, tutorials, extinguish,
# Nearest to san: conclave, palaeologus, santa, ave, impressionists, unusual, conservatory, josh,
# Nearest to question: illumination, wwf, supervises, simplicity, pitfalls, syllogism, sadc, wavy,
# Nearest to institute: also, colleges, statewide, medical, public, scandals, lublin, university,
# Nearest to existence: lengths, entails, wide, constructions, evidenced, indeed, stitch, involution,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.0665 0.3581 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1354 0.3481 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1175 0.3337 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.0921 0.3097 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.0219 0.3130 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.0485 0.3371 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 3.9530 0.3450 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.0442 0.3445 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.0661 0.3482 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.0242 0.3467 sec/batch
# Nearest to as: nations, serving, various, performers, algae, immensely, compare, pertain,
# Nearest to its: sealand, encompassing, largely, sectors, bg, approving, biscuit, aquaria,
# Nearest to see: celebrating, nullify, punctuation, redirects, external, etymologies, article, outlining,
# Nearest to which: agricultural, superset, speculated, bigg, valhalla, mb, perhaps, foo,
# Nearest to who: brother, agar, consented, charting, crimson, ditka, advised, continue,
# Nearest to use: mandriva, aac, hydrophilic, available, discount, manama, risk, fallacies,
# Nearest to years: four, female, population, bonewits, mortality, year, migrant, male,
# Nearest to most: oddities, innovations, preserved, mammoths, shooters, hd, shipment, lisbon,
# Nearest to consists: the, discharges, isosceles, quetta, are, peach, reciprocity, form,
# Nearest to discovered: colony, residues, delicate, mosaics, cassini, emulsion, misquoted, comet,
# Nearest to experience: versus, intelligent, peaking, themes, neighborhoods, wagon, marginal, aesthetics,
# Nearest to applications: resistor, mozilla, applets, embed, microsoft, extinguish, tutorials, polymer,
# Nearest to san: ave, unusual, palaeologus, conclave, santa, angeles, conservatory, impressionists,
# Nearest to question: wwf, illumination, supervises, pitfalls, simplicity, syllogism, wavy, subtlety,
# Nearest to institute: colleges, also, medical, statewide, institutes, lublin, honorary, school,
# Nearest to existence: lengths, wide, entails, nippur, constructions, evidenced, reformers, seemingly,
# Epoch 4/10 Iteration: 13100 Avg. Training loss: 4.0832 0.1748 sec/batch
# Epoch 4/10 Iteration: 13200 Avg. Training loss: 4.0097 0.3104 sec/batch
# Epoch 4/10 Iteration: 13300 Avg. Training loss: 3.9907 0.3543 sec/batch
# Epoch 4/10 Iteration: 13400 Avg. Training loss: 4.0270 0.3497 sec/batch
# Epoch 4/10 Iteration: 13500 Avg. Training loss: 3.9629 0.3505 sec/batch
# Epoch 4/10 Iteration: 13600 Avg. Training loss: 3.9686 0.3501 sec/batch
# Epoch 4/10 Iteration: 13700 Avg. Training loss: 3.9865 0.3723 sec/batch
# Epoch 4/10 Iteration: 13800 Avg. Training loss: 4.0274 0.3525 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.0231 0.3698 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0517 0.3610 sec/batch
# Nearest to as: nations, serving, performers, algae, immensely, gibraltarians, alastair, various,
# Nearest to its: sealand, aquaria, largely, encompassing, bg, nitrogen, biscuit, extensive,
# Nearest to see: nullify, celebrating, punctuation, external, redirects, article, etymologies, outlining,
# Nearest to which: speculated, valhalla, agricultural, perhaps, bigg, by, comprise, taurus,
# Nearest to who: brother, agar, consented, crimson, charting, called, ditka, archaic,
# Nearest to use: mandriva, manama, hen, marijuana, khalifa, aac, discount, hydrophilic,
# Nearest to years: four, bonewits, female, population, year, mortality, live, two,
# Nearest to most: oddities, innovations, shooters, preserved, mammoths, shipment, hd, adherence,
# Nearest to consists: discharges, isosceles, form, the, quetta, peach, are, reciprocity,
# Nearest to discovered: colony, residues, cassini, mosaics, delicate, settled, emulsion, comet,
# Nearest to experience: intelligent, versus, dosage, peaking, marginal, themes, suffering, neighborhoods,
# Nearest to applications: resistor, mozilla, applets, embed, extinguish, microsoft, chekhov, tutorials,
# Nearest to san: ave, unusual, conclave, santa, opted, impressionists, conservatory, penguins,
# Nearest to question: supervises, wwf, illumination, pitfalls, syllogism, simplicity, overt, complete,
# Nearest to institute: medical, colleges, statewide, institutes, also, honorary, rigorous, public,
# Nearest to existence: lengths, wide, entails, nippur, indeed, evidenced, seemingly, reformers,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 3.9733 0.3913 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 3.9451 0.3589 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 3.9789 0.3564 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 3.9387 0.3569 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 3.9882 0.3561 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0369 0.3532 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 3.9880 0.3119 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 3.9496 0.3139 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.0589 0.3337 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.9702 0.3287 sec/batch
# Nearest to as: algae, forms, serving, nations, complex, performers, often, particulate,
# Nearest to its: sealand, aquaria, encompassing, largely, bg, nitrogen, extensive, privileged,
# Nearest to see: celebrating, nullify, punctuation, external, article, redirects, bibliography, distributive,
# Nearest to which: agricultural, by, comprise, valhalla, mb, bigg, superset, secession,
# Nearest to who: brother, agar, crimson, charting, called, consented, continue, sold,
# Nearest to use: mandriva, manama, numeric, hen, hydrophilic, discount, available, abjad,
# Nearest to years: four, population, female, bonewits, mortality, live, year, migrant,
# Nearest to most: innovations, preserved, it, hd, oddities, shooters, mammoths, adherence,
# Nearest to consists: isosceles, the, discharges, are, peach, form, quetta, steered,
# Nearest to discovered: colony, comet, mosaics, settled, emulsion, cassini, delicate, residues,
# Nearest to experience: intelligent, versus, dosage, themes, aesthetics, marginal, suffering, precursors,
# Nearest to applications: resistor, mozilla, applets, extinguish, chekhov, polymer, embed, tutorials,
# Nearest to san: santa, ave, unusual, conclave, conservatory, nacional, opted, angeles,
# Nearest to question: supervises, illumination, pitfalls, wwf, syllogism, simplicity, wavy, else,
# Nearest to institute: colleges, institutes, statewide, medical, also, honorary, rigorous, public,
# Nearest to existence: lengths, wide, entails, nippur, involution, endeavour, reformers, feminists,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.9714 0.3356 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0316 0.3123 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9884 0.3223 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 3.9906 0.3083 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0191 0.3097 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 3.9715 0.3148 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 3.9970 0.3472 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 3.9986 0.3107 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0284 0.3217 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0002 0.3193 sec/batch
# Nearest to as: nations, serving, immensely, performers, pertain, separation, complex, algae,
# Nearest to its: sealand, encompassing, bg, aquaria, extensive, recaptured, independence, largely,
# Nearest to see: celebrating, nullify, article, external, punctuation, redirects, distributive, universals,
# Nearest to which: agricultural, by, secession, valhalla, regimental, comprise, richard, speculated,
# Nearest to who: brother, agar, called, advised, continue, charting, consented, crimson,
# Nearest to use: mandriva, manama, available, discount, supplementary, hen, numeric, khalifa,
# Nearest to years: four, female, population, mortality, bonewits, year, migrant, live,
# Nearest to most: preserved, adherence, innovations, oddities, shooters, it, human, mammoths,
# Nearest to consists: isosceles, the, discharges, are, quetta, peach, form, reciprocity,
# Nearest to discovered: colony, settled, mosaics, comet, cassini, emulsion, delicate, residues,
# Nearest to experience: versus, intelligent, dosage, aesthetics, themes, peaking, neighborhoods, suffering,
# Nearest to applications: resistor, mozilla, applets, extinguish, chekhov, polymer, embed, plosives,
# Nearest to san: conclave, santa, ave, unusual, impressionists, palaeologus, conservatory, lecturer,
# Nearest to question: pitfalls, supervises, wwf, syllogism, simplicity, wavy, subtlety, illumination,
# Nearest to institute: colleges, institutes, statewide, medical, rigorous, public, accommodated, also,
# Nearest to existence: lengths, wide, entails, feminists, nippur, endeavour, involution, god,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 3.9642 0.3711 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 3.9550 0.3860 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0042 0.3393 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 3.9584 0.3506 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0387 0.3420 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0391 0.3590 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0456 0.3364 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 3.9420 0.3179 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 3.9365 0.3577 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 3.9630 0.3208 sec/batch
# Nearest to as: serving, performers, nations, algae, often, immensely, gibraltarians, announcing,
# Nearest to its: encompassing, sealand, aquaria, bg, independence, extensive, largely, privileged,
# Nearest to see: celebrating, nullify, external, article, punctuation, redirects, universals, etymologies,
# Nearest to which: agricultural, by, valhalla, bigg, mb, gis, foo, secession,
# Nearest to who: brother, agar, called, advised, continue, consented, relinquish, been,
# Nearest to use: mandriva, abjad, numeric, manama, hen, khalifa, hydrophilic, fallacies,
# Nearest to years: four, female, mortality, bonewits, population, year, live, migrant,
# Nearest to most: innovations, preserved, molybdenum, shooters, it, oddities, adherence, lisbon,
# Nearest to consists: the, isosceles, are, discharges, form, quetta, peach, unitary,
# Nearest to discovered: colony, settled, mosaics, sprague, cassini, comet, aurelius, residues,
# Nearest to experience: intelligent, versus, dosage, peaking, aesthetics, themes, neighborhoods, suffering,
# Nearest to applications: resistor, mozilla, applets, extinguish, chekhov, microsoft, engines, tutorials,
# Nearest to san: santa, ave, conclave, unusual, impressionists, conservatory, angeles, josh,
# Nearest to question: pitfalls, wwf, supervises, subtlety, subscriptions, illumination, syllogism, simplicity,
# Nearest to institute: institutes, colleges, honorary, statewide, rigorous, medical, admissions, public,
# Nearest to existence: lengths, wide, entails, nippur, feminists, peterson, endeavour, involution,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 3.8948 0.3145 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9774 0.3304 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 3.9405 0.3301 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0084 0.3259 sec/batch
# Epoch 5/10 Iteration: 17500 Avg. Training loss: 3.9750 0.3380 sec/batch
# Epoch 5/10 Iteration: 17600 Avg. Training loss: 3.9328 0.3368 sec/batch
# Epoch 5/10 Iteration: 17700 Avg. Training loss: 3.9592 0.3283 sec/batch
# Epoch 5/10 Iteration: 17800 Avg. Training loss: 3.9355 0.3301 sec/batch
# Epoch 5/10 Iteration: 17900 Avg. Training loss: 3.9287 0.3421 sec/batch
# Epoch 5/10 Iteration: 18000 Avg. Training loss: 3.9402 0.3482 sec/batch
# Nearest to as: serving, nations, performers, often, algae, immensely, name, gibraltarians,
# Nearest to its: aquaria, bg, sealand, nitrogen, encompassing, extensive, erlang, vanes,
# Nearest to see: celebrating, nullify, external, punctuation, article, universals, redirects, distributive,
# Nearest to which: by, agricultural, comprise, valhalla, perhaps, secession, maghreb, encompassed,
# Nearest to who: brother, agar, continue, been, faithfully, everlasting, geraldine, charting,
# Nearest to use: mandriva, abjad, manama, derives, khalifa, risk, numeric, hen,
# Nearest to years: four, bonewits, mortality, female, year, population, migrant, two,
# Nearest to most: innovations, shooters, preserved, molybdenum, oddities, it, adherence, computable,
# Nearest to consists: are, the, isosceles, discharges, form, peach, reciprocity, abbreviations,
# Nearest to discovered: colony, settled, comet, cassini, sprague, mosaics, priestley, emulsion,
# Nearest to experience: intelligent, versus, dosage, suffering, neighborhoods, peaking, aesthetics, marginal,
# Nearest to applications: resistor, mozilla, applets, extinguish, chekhov, embed, microsoft, plosives,
# Nearest to san: santa, ave, conclave, unusual, opted, impressionists, conservatory, nacional,
# Nearest to question: pitfalls, wwf, supervises, syllogism, subtlety, illumination, else, saying,
# Nearest to institute: institutes, colleges, honorary, rigorous, medical, statewide, academy, consultants,
# Nearest to existence: lengths, entails, wide, feminists, nippur, god, involution, evidenced,
# Epoch 5/10 Iteration: 18100 Avg. Training loss: 3.9012 0.3823 sec/batch
# Epoch 5/10 Iteration: 18200 Avg. Training loss: 3.9780 0.3836 sec/batch
# Epoch 5/10 Iteration: 18300 Avg. Training loss: 3.9079 0.3322 sec/batch
# Epoch 5/10 Iteration: 18400 Avg. Training loss: 3.9843 0.3232 sec/batch
# Epoch 5/10 Iteration: 18500 Avg. Training loss: 3.8369 0.3165 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 3.9191 0.3359 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.8830 0.3589 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.8780 0.3660 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9215 0.3377 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.8856 0.3412 sec/batch
# Nearest to as: often, algae, nations, performers, serving, forms, name, mechanization,
# Nearest to its: aquaria, nitrogen, encompassing, sealand, bg, extensive, erlang, approving,
# Nearest to see: celebrating, nullify, external, article, punctuation, distributive, universals, redirects,
# Nearest to which: by, comprise, valhalla, agricultural, bigg, perhaps, undergoes, manifest,
# Nearest to who: brother, agar, continue, faithfully, everlasting, fulfilling, geraldine, called,
# Nearest to use: manama, mandriva, numeric, abjad, marijuana, derives, supplementary, hen,
# Nearest to years: four, bonewits, population, mortality, female, year, live, two,
# Nearest to most: shooters, preserved, adherence, innovations, it, molybdenum, computable, professional,
# Nearest to consists: the, are, isosceles, form, discharges, of, consisting, peach,
# Nearest to discovered: settled, comet, colony, cassini, sprague, priestley, emulsion, aurelius,
# Nearest to experience: intelligent, versus, suffering, dosage, peaking, marginal, aesthetics, neighborhoods,
# Nearest to applications: resistor, mozilla, extinguish, applets, chekhov, embed, polymer, tutorials,
# Nearest to san: santa, ave, conclave, nacional, josh, impressionists, francisco, unusual,
# Nearest to question: pitfalls, syllogism, supervises, wwf, illumination, subtlety, else, complete,
# Nearest to institute: institutes, colleges, honorary, rigorous, statewide, medical, academy, public,
# Nearest to existence: lengths, entails, nippur, feminists, wide, involution, endeavour, god,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.8937 0.3291 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9451 0.3153 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9573 0.3491 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9074 0.3615 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9123 0.3110 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9384 0.3148 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9630 0.3189 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9250 0.3264 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9215 0.3193 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9277 0.3299 sec/batch
# Nearest to as: often, performers, serving, algae, nations, name, complex, forms,
# Nearest to its: encompassing, aquaria, nitrogen, sealand, independence, erlang, bg, canyon,
# Nearest to see: external, celebrating, article, nullify, universals, distributive, punctuation, uses,
# Nearest to which: by, undergoes, agricultural, comprise, bigg, perhaps, valhalla, gis,
# Nearest to who: brother, agar, continue, geraldine, relinquish, advised, consented, fulfilling,
# Nearest to use: mandriva, supplementary, manama, numeric, uses, hen, abjad, precision,
# Nearest to years: four, female, population, mortality, year, bonewits, two, live,
# Nearest to most: preserved, adherence, shooters, professional, innovations, oddities, it, molybdenum,
# Nearest to consists: the, are, isosceles, peach, discharges, consisting, form, legislative,
# Nearest to discovered: settled, colony, comet, cassini, priestley, probes, sprague, emulsion,
# Nearest to experience: intelligent, suffering, versus, peaking, aesthetics, neighborhoods, dosage, wagon,
# Nearest to applications: resistor, mozilla, applets, extinguish, chekhov, embed, tutorials, engines,
# Nearest to san: santa, conclave, ave, unusual, francisco, josh, impressionists, nacional,
# Nearest to question: wwf, pitfalls, syllogism, supervises, illumination, subtlety, else, berry,
# Nearest to institute: institutes, colleges, rigorous, honorary, consultants, accommodated, academy, statewide,
# Nearest to existence: lengths, entails, wide, nippur, involution, peterson, feminists, endeavour,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9513 0.3242 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9342 0.3214 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9398 0.3166 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9304 0.3380 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 3.8808 0.3630 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9016 0.3524 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9536 0.3326 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9301 0.3865 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0018 0.3584 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9969 0.3450 sec/batch
# Nearest to as: serving, performers, name, nations, often, announcing, objected, status,
# Nearest to its: independence, approving, sealand, aquaria, nitrogen, encompassing, bactria, erlang,
# Nearest to see: external, celebrating, article, nullify, punctuation, distributive, ministry, universals,
# Nearest to which: by, agricultural, mb, secession, perhaps, gis, undergoes, litigants,
# Nearest to who: brother, continue, agar, been, geraldine, fulfilling, relinquish, advised,
# Nearest to use: manama, mandriva, hen, khalifa, supplementary, derives, uses, abjad,
# Nearest to years: four, year, female, mortality, bonewits, population, two, live,
# Nearest to most: preserved, shooters, adherence, innovations, it, professional, powerful, hd,
# Nearest to consists: the, are, isosceles, legislative, peach, discharges, consisting, abbreviations,
# Nearest to discovered: settled, colony, comet, probes, cassini, priestley, sprague, aurelius,
# Nearest to experience: intelligent, peaking, aesthetics, suffering, versus, themes, neighborhoods, havens,
# Nearest to applications: mozilla, resistor, applets, extinguish, chekhov, embed, engines, tutorials,
# Nearest to san: santa, conclave, ave, francisco, josh, unusual, impressionists, nacional,
# Nearest to question: wwf, pitfalls, supervises, subscriptions, syllogism, subtlety, illumination, else,
# Nearest to institute: institutes, honorary, colleges, rigorous, consultants, accommodated, academy, medical,
# Nearest to existence: lengths, nippur, entails, wide, feminists, peterson, lagoon, involution,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9318 0.3177 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.8786 0.3229 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9100 0.3096 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.8091 0.3217 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9164 0.3106 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9177 0.3172 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.8951 0.3135 sec/batch
# Epoch 6/10 Iteration: 21800 Avg. Training loss: 3.9389 0.1609 sec/batch
# Epoch 6/10 Iteration: 21900 Avg. Training loss: 3.8699 0.3090 sec/batch
# Epoch 6/10 Iteration: 22000 Avg. Training loss: 3.8759 0.3126 sec/batch
# Nearest to as: name, often, performers, serving, nations, algae, gibraltarians, forms,
# Nearest to its: aquaria, nitrogen, sealand, approving, gts, encompassing, independence, bactria,
# Nearest to see: external, celebrating, article, nullify, punctuation, universals, distributive, for,
# Nearest to which: by, undergoes, perhaps, bigg, comprise, valhalla, secession, richard,
# Nearest to who: brother, continue, agar, been, geraldine, imaginary, faithfully, fulfilling,
# Nearest to use: mandriva, manama, derives, uses, hen, supplementary, resembles, numeric,
# ...
# Epoch 9/10 Iteration: 36000 Avg. Training loss: 3.8162 0.3695 sec/batch
# Nearest to as: of, the, from, is, and, in, with, name,
# Nearest to its: the, from, and, of, gts, aquaria, micro, by,
# Nearest to see: of, external, article, also, for, disambiguation, the, uses,
# Nearest to which: by, the, a, is, in, of, this, undergoes,
# Nearest to who: brother, been, old, geraldine, fulfilling, continue, those, faithfully,
# Nearest to use: uses, used, derives, or, supplementary, mandriva, precautions, modern,
# Nearest to years: year, live, four, female, population, migrant, zero, two,
# Nearest to most: and, in, widely, it, powerful, notable, preserved, a,
# Nearest to consists: of, consisting, branches, the, peach, handle, abbreviated, are,
# Nearest to discovered: settled, conclusively, priestley, probes, discovery, humphry, had, comet,
# Nearest to experience: dosage, peaking, suffering, undemocratic, priori, responsive, havens, versus,
# Nearest to applications: mozilla, embed, extinguish, engines, resistor, unreachable, revere, applets,
# Nearest to san: francisco, santa, nacional, conclave, diego, serrano, ave, premiere,
# Nearest to question: asks, whether, pitfalls, flashback, supervises, belli, beverly, berry,
# Nearest to institute: honorary, institutes, colleges, academy, ceramics, balochistan, touted, urbana,
# Nearest to existence: lengths, nippur, entails, sharpened, lavos, wide, marlow, tolstoy,
# Epoch 9/10 Iteration: 36100 Avg. Training loss: 3.7563 0.3707 sec/batch
# Epoch 9/10 Iteration: 36200 Avg. Training loss: 3.7664 0.3559 sec/batch
# Epoch 9/10 Iteration: 36300 Avg. Training loss: 3.8131 0.3582 sec/batch
# Epoch 9/10 Iteration: 36400 Avg. Training loss: 3.7926 0.3908 sec/batch
# Epoch 9/10 Iteration: 36500 Avg. Training loss: 3.7836 0.3328 sec/batch
# Epoch 9/10 Iteration: 36600 Avg. Training loss: 3.8435 0.3226 sec/batch
# Epoch 9/10 Iteration: 36700 Avg. Training loss: 3.8265 0.3292 sec/batch
# Epoch 9/10 Iteration: 36800 Avg. Training loss: 3.8094 0.3257 sec/batch
# Epoch 9/10 Iteration: 36900 Avg. Training loss: 3.7946 0.3277 sec/batch
# Epoch 9/10 Iteration: 37000 Avg. Training loss: 3.8227 0.3240 sec/batch
# Nearest to as: of, the, is, from, in, and, often, with,
# Nearest to its: from, the, gts, aquaria, of, micro, in, and,
# Nearest to see: of, external, also, article, for, disambiguation, uses, list,
# Nearest to which: the, by, a, of, is, this, very, in,
# Nearest to who: brother, been, geraldine, those, old, fulfilling, continue, having,
# Nearest to use: uses, derives, used, supplementary, mandriva, or, precautions, also,
# Nearest to years: year, live, female, four, zero, mortality, migrant, population,
# Nearest to most: widely, and, powerful, it, in, notable, preserved, a,
# Nearest to consists: of, the, consisting, branches, are, handle, peach, abbreviated,
# Nearest to discovered: conclusively, settled, priestley, discovery, had, humphry, comet, probes,
# Nearest to experience: dosage, peaking, suffering, priori, responsive, havens, undemocratic, potentials,
# Nearest to applications: mozilla, embed, extinguish, unreachable, engines, revere, resistor, mandrake,
# Nearest to san: francisco, santa, nacional, conclave, ave, diego, serrano, premiere,
# Nearest to question: asks, whether, pitfalls, answered, supervises, flashback, beverly, berry,
# Nearest to institute: honorary, colleges, institutes, academy, ceramics, balochistan, urbana, ut,
# Nearest to existence: lengths, nippur, sharpened, entails, lavos, marlow, wide, refutation,
# Epoch 9/10 Iteration: 37100 Avg. Training loss: 3.8439 0.3293 sec/batch
# Epoch 9/10 Iteration: 37200 Avg. Training loss: 3.8003 0.3196 sec/batch
# Epoch 9/10 Iteration: 37300 Avg. Training loss: 3.7967 0.3210 sec/batch
# Epoch 9/10 Iteration: 37400 Avg. Training loss: 3.8070 0.3243 sec/batch
# Epoch 9/10 Iteration: 37500 Avg. Training loss: 3.8347 0.3317 sec/batch
# Epoch 9/10 Iteration: 37600 Avg. Training loss: 3.8455 0.3251 sec/batch
# Epoch 9/10 Iteration: 37700 Avg. Training loss: 3.8269 0.3168 sec/batch
# Epoch 9/10 Iteration: 37800 Avg. Training loss: 3.8069 0.3111 sec/batch
# Epoch 9/10 Iteration: 37900 Avg. Training loss: 3.7944 0.3326 sec/batch
# Epoch 9/10 Iteration: 38000 Avg. Training loss: 3.7906 0.3540 sec/batch
# Nearest to as: of, the, is, and, in, with, often, from,
# Nearest to its: of, the, from, in, and, a, by, gts,
# Nearest to see: of, external, also, article, for, disambiguation, uses, the,
# Nearest to which: by, the, a, in, is, of, this, to,
# Nearest to who: brother, been, themselves, geraldine, those, continue, whom, fulfilling,
# Nearest to use: uses, used, derives, or, have, mandriva, supplementary, a,
# Nearest to years: year, live, mortality, female, zero, population, migrant, four,
# Nearest to most: and, widely, in, it, powerful, preserved, a, the,
# Nearest to consists: of, consisting, the, branches, are, handle, peach, abbreviated,
# Nearest to discovered: conclusively, settled, had, probes, priestley, discovery, lived, comet,
# Nearest to experience: dosage, peaking, havens, responsive, priori, suffering, versus, potentials,
# Nearest to applications: mozilla, embed, extinguish, unreachable, revere, engines, mandrake, resistor,
# Nearest to san: francisco, santa, conclave, nacional, serrano, ave, diego, premiere,
# Nearest to question: asks, whether, pitfalls, swaps, flashback, beverly, smallest, supervises,
# Nearest to institute: honorary, colleges, institutes, academy, balochistan, ceramics, ut, urbana,
# Nearest to existence: lengths, nippur, sharpened, entails, lavos, marlow, refutation, wide,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 3.8651 0.3137 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.8096 0.3380 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8882 0.3130 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.8902 0.3078 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8499 0.3090 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.7642 0.3142 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.7915 0.3117 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.7193 0.3525 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8221 0.3204 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8215 0.3325 sec/batch
# Nearest to as: of, is, the, in, often, with, from, also,
# Nearest to its: from, the, of, in, gts, and, aquaria, micro,
# Nearest to see: of, also, external, article, disambiguation, for, uses, links,
# Nearest to which: the, by, a, is, in, of, also, this,
# Nearest to who: brother, been, geraldine, anakin, old, whom, imaginary, those,
# Nearest to use: uses, used, derives, or, mandriva, precautions, supplementary, also,
# Nearest to years: year, female, zero, migrant, mortality, live, two, population,
# Nearest to most: widely, and, in, it, notable, powerful, preserved, the,
# Nearest to consists: consisting, of, branches, are, the, handle, peach, solely,
# Nearest to discovered: had, conclusively, settled, probes, discovery, priestley, comet, lived,
# Nearest to experience: dosage, responsive, peaking, suffering, priori, havens, uninterrupted, apathy,
# Nearest to applications: mozilla, engines, extinguish, embed, unreachable, mandrake, revere, resistor,
# Nearest to san: francisco, santa, nacional, conclave, serrano, diego, premiere, ave,
# Nearest to question: asks, whether, swaps, flashback, pitfalls, answered, beverly, hypothesis,
# Nearest to institute: institutes, honorary, colleges, academy, ceramics, urbana, balochistan, ut,
# Nearest to existence: nippur, lengths, lavos, sharpened, marlow, reformers, entails, trams,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8024 0.3227 sec/batch
# Epoch 10/10 Iteration: 39200 Avg. Training loss: 3.8721 0.1796 sec/batch
# Epoch 10/10 Iteration: 39300 Avg. Training loss: 3.7807 0.3579 sec/batch
# Epoch 10/10 Iteration: 39400 Avg. Training loss: 3.7970 0.3595 sec/batch
# Epoch 10/10 Iteration: 39500 Avg. Training loss: 3.8291 0.3533 sec/batch
# Epoch 10/10 Iteration: 39600 Avg. Training loss: 3.7626 0.3419 sec/batch
# Epoch 10/10 Iteration: 39700 Avg. Training loss: 3.7848 0.3168 sec/batch
# Epoch 10/10 Iteration: 39800 Avg. Training loss: 3.7518 0.3222 sec/batch
# Epoch 10/10 Iteration: 39900 Avg. Training loss: 3.8105 0.3141 sec/batch
# Epoch 10/10 Iteration: 40000 Avg. Training loss: 3.8096 0.3168 sec/batch
# Nearest to as: of, the, in, is, from, and, with, name,
# Nearest to its: from, the, and, in, of, aquaria, gts, came,
# Nearest to see: of, external, also, article, disambiguation, for, uses, based,
# Nearest to which: the, by, in, a, of, is, this, to,
# Nearest to who: brother, been, old, those, geraldine, whom, anakin, themselves,
# Nearest to use: uses, used, derives, or, precautions, mandriva, supplementary, manama,
# Nearest to years: year, live, four, female, migrant, zero, age, mortality,
# Nearest to most: and, widely, in, it, powerful, a, notable, the,
# Nearest to consists: consisting, of, are, branches, peach, the, handle, entitled,
# Nearest to discovered: conclusively, settled, had, probes, comet, priestley, discovery, lived,
# Nearest to experience: dosage, peaking, responsive, suffering, priori, havens, uninterrupted, philosophical,
# Nearest to applications: mozilla, embed, engines, unreachable, revere, resistor, mandrake, extinguish,
# Nearest to san: francisco, santa, diego, nacional, conclave, serrano, ave, premiere,
# Nearest to question: asks, whether, flashback, answered, hypothesis, jun, swaps, beverly,
# Nearest to institute: honorary, institutes, colleges, academy, ceramics, urbana, balochistan, ut,
# Nearest to existence: nippur, lengths, lavos, sharpened, entails, marlow, universe, refutation,
# Epoch 10/10 Iteration: 40100 Avg. Training loss: 3.8216 0.3138 sec/batch
# Epoch 10/10 Iteration: 40200 Avg. Training loss: 3.7852 0.3087 sec/batch
# Epoch 10/10 Iteration: 40300 Avg. Training loss: 3.7506 0.3067 sec/batch
# Epoch 10/10 Iteration: 40400 Avg. Training loss: 3.7818 0.3144 sec/batch
# Epoch 10/10 Iteration: 40500 Avg. Training loss: 3.6981 0.3102 sec/batch
# Epoch 10/10 Iteration: 40600 Avg. Training loss: 3.7741 0.3514 sec/batch
# Epoch 10/10 Iteration: 40700 Avg. Training loss: 3.8136 0.3349 sec/batch
# Epoch 10/10 Iteration: 40800 Avg. Training loss: 3.7989 0.3506 sec/batch
# Epoch 10/10 Iteration: 40900 Avg. Training loss: 3.7609 0.3091 sec/batch
# Epoch 10/10 Iteration: 41000 Avg. Training loss: 3.8725 0.3124 sec/batch
# Nearest to as: of, is, the, in, a, often, and, with,
# Nearest to its: the, from, of, and, gts, in, aquaria, a,
# Nearest to see: of, also, external, article, disambiguation, for, uses, the,
# Nearest to which: the, by, a, of, this, is, in, very,
# Nearest to who: brother, geraldine, been, anakin, those, old, fulfilling, whom,
# Nearest to use: uses, used, derives, or, supplementary, precautions, have, also,
# Nearest to years: year, age, live, zero, four, female, migrant, mortality,
# Nearest to most: widely, and, it, in, notable, powerful, preserved, shooters,
# Nearest to consists: of, consisting, are, branches, the, peach, handle, entitled,
# Nearest to discovered: conclusively, discovery, settled, had, priestley, lived, comet, humphry,
# Nearest to experience: dosage, suffering, peaking, responsive, priori, potentials, uninterrupted, apathy,
# Nearest to applications: mozilla, embed, engines, revere, resistor, mandrake, unreachable, extinguish,
# Nearest to san: francisco, santa, nacional, diego, conclave, serrano, ave, angeles,
# Nearest to question: asks, whether, hypothesis, smallest, swaps, conclusion, that, answered,
# Nearest to institute: colleges, academy, institutes, honorary, urbana, ceramics, ut, ams,
# Nearest to existence: lengths, nippur, lavos, sharpened, entails, marlow, universe, ae,
# Epoch 10/10 Iteration: 41100 Avg. Training loss: 3.7752 0.3104 sec/batch
# Epoch 10/10 Iteration: 41200 Avg. Training loss: 3.7664 0.3136 sec/batch
# Epoch 10/10 Iteration: 41300 Avg. Training loss: 3.7931 0.3143 sec/batch
# Epoch 10/10 Iteration: 41400 Avg. Training loss: 3.8086 0.3186 sec/batch
# Epoch 10/10 Iteration: 41500 Avg. Training loss: 3.7990 0.3423 sec/batch
# Epoch 10/10 Iteration: 41600 Avg. Training loss: 3.8361 0.3502 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.7929 0.3735 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.7925 0.3601 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8213 0.3708 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8050 0.3722 sec/batch
# Nearest to as: of, is, the, in, and, a, from, often,
# Nearest to its: the, from, of, and, in, a, by, gts,
# Nearest to see: of, also, external, article, for, disambiguation, the, in,
# Nearest to which: by, the, a, in, is, of, this, but,
# Nearest to who: brother, geraldine, been, those, anakin, continue, fulfilling, old,
# Nearest to use: uses, used, derives, or, mandriva, precautions, supplementary, have,
# Nearest to years: year, zero, age, live, four, female, migrant, mortality,
# Nearest to most: and, widely, in, it, notable, powerful, the, preserved,
# Nearest to consists: of, the, consisting, are, branches, peach, see, handle,
# Nearest to discovered: conclusively, had, discovery, settled, lived, priestley, probes, comet,
# Nearest to experience: responsive, priori, peaking, dosage, suffering, versus, philosophical, havens,
# Nearest to applications: mozilla, embed, revere, engines, mandrake, unreachable, resistor, deficiency,
# Nearest to san: francisco, santa, nacional, diego, serrano, conclave, premiere, ave,
# Nearest to question: asks, whether, hypothesis, conclusion, answered, swaps, jun, flashback,
# Nearest to institute: academy, colleges, institutes, honorary, ceramics, urbana, ut, ams,
# Nearest to existence: lengths, nippur, lavos, sharpened, entails, marlow, reformers, trams,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8090 0.3150 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.7686 0.3675 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7747 0.3600 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8344 0.3620 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.7798 0.3501 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8948 0.3650 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8612 0.3259 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.8454 0.3109 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7538 0.3138 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7184 0.3152 sec/batch
# Nearest to as: in, the, is, of, and, often, with, from,
# Nearest to its: the, of, and, from, in, a, with, came,
# Nearest to see: of, also, external, article, disambiguation, the, for, links,
# Nearest to which: by, the, a, in, is, this, to, of,
# Nearest to who: brother, been, old, anakin, geraldine, whom, those, early,
# Nearest to use: uses, used, derives, or, mandriva, such, a, precautions,
# Nearest to years: year, age, four, zero, live, female, migrant, two,
# Nearest to most: and, in, widely, the, it, notable, powerful, preserved,
# Nearest to consists: consisting, of, are, branches, the, peach, entitled, abbreviated,
# Nearest to discovered: had, conclusively, lived, probes, settled, discovery, priestley, comet,
# Nearest to experience: responsive, peaking, dosage, priori, havens, philosophical, angell, suffering,
# Nearest to applications: mozilla, revere, embed, mandrake, engines, unreachable, extinguish, office,
# Nearest to san: francisco, santa, nacional, diego, serrano, premiere, conclave, concepci,
# Nearest to question: asks, whether, hypothesis, swaps, conclusion, answered, answer, jun,
# Nearest to institute: institutes, honorary, colleges, academy, ut, ceramics, urbana, ams,
# Nearest to existence: lengths, nippur, lavos, trams, marlow, sharpened, entails, universe,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.8128 0.3248 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.7748 7.1212 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8106 0.3872 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.7517 0.3657 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8103 0.3354 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
