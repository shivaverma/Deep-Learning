# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time
import utils
import numpy as np
import tensorflow as tf
from collections import Counter

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ### Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'of', 'the', 'french', 'revolution', 'whilst', 'the']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16535801
# Unique words: 44611

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
word_counts, vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %%
word_counts.most_common(10)
# Out:
# [('the', 1061396),
#  ('of', 593677),
#  ('and', 416629),
#  ('one', 411764),
#  ('in', 372201),
#  ('a', 325873),
#  ('to', 316376),
#  ('zero', 264975),
#  ('nine', 250430),
#  ('two', 192644)]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
thresh = 1e-5
total_count = len(int_words)

prob_words = Counter()

for word in word_counts:
    
    freq = word_counts[word]/total_count
    prob_words[word] = 1 - np.sqrt(thresh/freq)

# %%
prob_words.most_common(10)
# Out:
# [('the', 0.9875182955382383),
#  ('of', 0.9833107236279582),
#  ('and', 0.9800777736355261),
#  ('one', 0.9799604284725977),
#  ('in', 0.9789222693331915),
#  ('a', 0.9774737744035631),
#  ('to', 0.9771381772591387),
#  ('zero', 0.9750189799380377),
#  ('nine', 0.9743037681690123),
#  ('two', 0.9707022091094176)]

# %%
len(vocab_to_int), len(int_to_vocab)
# Out:
# (44611, 44611)

# %%
train_words = list()

for i in int_words:   
    if prob_words[int_to_vocab[i]] < np.random.random():
        train_words.append(i)

# %%
len(int_words), len(train_words)
# Out:
# (16535801, 4470214)

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    
    ''' Get a list of words in a window around an index. '''
    
    rand = np.random.randint(1, window_size)
    
    return words[max(0,idx-rand):idx]+words[idx+1:idx+rand+1]

# %%
lis = ['a','b','c','d','e','f','g','h','i']

get_target(lis, 1, 5)
# Out:
# ['a', 'c']

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()

with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='input')
    labels = tf.placeholder(tf.int32, [None, None], name='output')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(vocab_to_int)
n_embedding =  200

with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample

n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random

with train_graph.as_default():
    
    valid_size = 16
    valid_window = 100
    
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, random.sample(range(1000,1000+valid_window), valid_size//2))
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-19-727170dcdae4>:14: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10
loss_list = list()

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs), "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100), "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
                loss_list.append(loss/100)
            
            if iteration % 3000 == 0:
                
                print('')
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)  
                print('')
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.3809 0.0261 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.3702 0.0226 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.2710 0.0226 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.3339 0.0226 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.2281 0.0225 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.2894 0.0226 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.3197 0.0226 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.2616 0.0226 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.1932 0.0226 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.2106 0.0227 sec/batch
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.2337 0.0225 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.1781 0.0225 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.1436 0.0226 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.0320 0.0225 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 4.9911 0.0226 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.0345 0.0226 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.9922 0.0227 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.9082 0.0225 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.8801 0.0226 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.8881 0.0225 sec/batch
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.7942 0.0226 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8269 0.0226 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.7828 0.0226 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.7329 0.0225 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7579 0.0224 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.7400 0.0225 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7093 0.0225 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7087 0.0227 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.6984 0.0227 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.6877 0.0225 sec/batch
#
# Nearest to will: vila, parting, fictitious, absorb, feels, broadband, fudge, forefront,
# Nearest to these: explicitly, talked, wrongdoing, gorillas, distribution, sch, worldwide, approximations,
# Nearest to there: aquinas, peers, ish, trough, controversial, emphasised, peculiar, usda,
# Nearest to with: democratically, behaviour, orleans, taliban, showtime, meets, bagpipe, alam,
# Nearest to for: alongside, ability, receiving, colby, rams, implemented, interlude, cabling,
# Nearest to about: cent, endothermic, monitoring, rejoined, dodge, capital, bioterrorism, claus,
# Nearest to zero: bordering, wimp, tons, businessweek, poland, technically, host, victorian,
# Nearest to such: whereby, dissimilar, miniseries, hoped, sem, obtained, politicians, ts,
# Nearest to units: industries, reforming, it, bleaching, hazardous, area, owens, ulema,
# Nearest to issue: expel, companions, burgesses, birds, statistically, toon, primo, guerillas,
# Nearest to heavy: gasp, affected, flocked, distributed, zinc, positron, tusk, dilmun,
# Nearest to square: housing, result, adjust, tip, mates, immortal, bystanders, transliterated,
# Nearest to award: played, peirce, edom, cuneiform, editors, diverting, exhibits, plugs,
# Nearest to woman: papers, futility, wally, reformulated, grass, bre, naturally, lyle,
# Nearest to notes: bigotry, settings, brackish, neil, firearm, thx, unedited, juan,
# Nearest to ocean: highs, allusion, pled, hurricane, sweeping, diplomatic, halloween, kalahari,
#
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.6681 0.0234 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.6507 0.0227 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.6720 0.0226 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6898 0.0227 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.6299 0.0226 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6465 0.0226 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6457 0.0227 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.6026 0.0226 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6080 0.0226 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.5892 0.0226 sec/batch
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.5695 0.0227 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6044 0.0226 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.5670 0.0226 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.5718 0.0226 sec/batch
# Epoch 2/10 Iteration: 4500 Avg. Training loss: 4.5499 0.0070 sec/batch
# Epoch 2/10 Iteration: 4600 Avg. Training loss: 4.5182 0.0226 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.4472 0.0226 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.4230 0.0225 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.4702 0.0226 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.3862 0.0227 sec/batch
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4322 0.0226 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4283 0.0225 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4157 0.0226 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.4025 0.0227 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4161 0.0226 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.3276 0.0227 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.3739 0.0227 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3580 0.0226 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.3733 0.0225 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.3565 0.0226 sec/batch
#
# Nearest to will: parting, vila, feels, fudge, efficiencies, schwann, functional, absorb,
# Nearest to these: explicitly, inertia, be, toriyama, gorillas, approximations, saboteurs, lighter,
# Nearest to there: trough, aquinas, usda, manner, ish, enforcement, peers, peculiar,
# Nearest to with: orleans, cor, meets, bulky, democratically, contact, showtime, modafinil,
# Nearest to for: implemented, ability, alongside, colby, rams, gaming, cabling, beta,
# Nearest to about: endothermic, bioterrorism, reassigned, monitoring, cent, outraged, rejoined, ward,
# Nearest to zero: two, eight, tons, wimp, three, hancock, one, est,
# Nearest to such: whereby, dissimilar, obtained, maturing, signals, masonry, explanation, not,
# Nearest to units: industries, bleaching, reforming, hazardous, area, edvac, salinity, satsuma,
# Nearest to issue: guerillas, toon, expel, companions, progress, burgesses, ono, centurion,
# Nearest to heavy: gasp, zinc, affected, distributed, dilmun, positron, estonians, operatic,
# Nearest to square: housing, tip, scorpion, bystanders, rotating, desegregation, vec, snowstorm,
# Nearest to award: played, edom, peirce, survivability, pulitzer, plugs, literature, cuneiform,
# Nearest to woman: wally, bre, lyle, reformulated, druidism, shoah, papers, futility,
# Nearest to notes: bigotry, brackish, marcella, descriptions, loops, neil, settings, unedited,
# Nearest to ocean: pacific, hurricane, radios, highs, pled, shortwave, sweeping, shale,
#
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.3679 0.0236 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.3333 0.0225 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.3436 0.0227 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3674 0.0226 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.2979 0.0227 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.3153 0.0226 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3611 0.0226 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3265 0.0226 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3151 0.0225 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3238 0.0226 sec/batch
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.2955 0.0226 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3015 0.0226 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3261 0.0226 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3169 0.0227 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.2969 0.0227 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.2992 0.0226 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.2664 0.0226 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.2936 0.0225 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.2382 0.0227 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3092 0.0226 sec/batch
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3179 0.0226 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3082 0.0225 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.2577 0.0226 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.2491 0.0226 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.2757 0.0227 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.1771 0.0227 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2373 0.0226 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.2190 0.0225 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2362 0.0226 sec/batch
# Epoch 3/10 Iteration: 9000 Avg. Training loss: 4.2163 0.0139 sec/batch
#
# Nearest to will: parting, vila, recites, harmattan, fictitious, fudge, feels, schwann,
# Nearest to these: explicitly, layering, inertia, horizontal, toriyama, approximations, wrongdoing, flour,
# Nearest to there: trough, manner, stewed, gigabit, aquinas, longbowmen, emphasised, ish,
# Nearest to with: cor, orleans, democratically, playback, decrees, momenta, bulky, qualia,
# Nearest to for: implemented, gaming, encrypting, alongside, ability, mat, fanfic, broadband,
# Nearest to about: bioterrorism, cent, ward, endothermic, monitoring, reassigned, outraged, capital,
# Nearest to zero: two, eight, one, three, est, na, tons, nine,
# Nearest to such: whereby, ts, dissimilar, questionable, maturing, hoped, obtained, constants,
# Nearest to units: bleaching, slowing, reforming, industries, edvac, potatoes, hazardous, abiogenesis,
# Nearest to issue: guerillas, expel, toon, burgesses, companions, statistically, progress, centurion,
# Nearest to heavy: gasp, zinc, affected, positron, dilmun, proliferated, estonians, flees,
# Nearest to square: housing, tip, scorpion, distances, vec, rotating, snowstorm, vaz,
# Nearest to award: played, edom, pulitzer, peirce, survivability, literature, garnering, internationalization,
# Nearest to woman: bre, wally, mortal, dolly, fertility, typhoid, shoah, lyle,
# Nearest to notes: loops, unedited, bigotry, brackish, descriptions, neil, settings, traversed,
# Nearest to ocean: hurricane, pacific, shortwave, radios, stations, highs, sail, meters,
#
# Epoch 3/10 Iteration: 9100 Avg. Training loss: 4.1710 0.0233 sec/batch
# Epoch 3/10 Iteration: 9200 Avg. Training loss: 4.1394 0.0228 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.1957 0.0225 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.1463 0.0227 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.1469 0.0226 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1046 0.0226 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2214 0.0225 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1641 0.0226 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.1604 0.0225 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1563 0.0225 sec/batch
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.0651 0.0225 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.1150 0.0225 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.0849 0.0226 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.0825 0.0225 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1439 0.0229 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1191 0.0226 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1203 0.0227 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1484 0.0224 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1156 0.0226 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1062 0.0226 sec/batch
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1390 0.0225 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.1109 0.0226 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1150 0.0225 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.0967 0.0226 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.0852 0.0225 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1114 0.0227 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1644 0.0228 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1115 0.0225 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1557 0.0225 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1288 0.0227 sec/batch
#
# Nearest to will: fudge, parting, schwann, vila, blank, feels, fictitious, harmattan,
# Nearest to these: explicitly, toriyama, lighter, layering, inertia, horizontal, pentecostalism, flour,
# Nearest to there: trough, longbowmen, aquinas, stewed, manner, median, gigabit, ish,
# Nearest to with: cor, decrees, democratically, orleans, maiden, alam, playback, satirists,
# Nearest to for: gaming, colby, mat, alongside, implemented, granada, cabling, rams,
# Nearest to about: ward, bioterrorism, monitoring, reassigned, cent, endothermic, reverses, point,
# Nearest to zero: two, one, eight, three, na, est, nine, businessweek,
# Nearest to such: whereby, questionable, dissimilar, ts, maturing, realistically, gpcrs, scholasticus,
# Nearest to units: bleaching, satsuma, slowing, edvac, owens, reforming, potatoes, abiogenesis,
# Nearest to issue: guerillas, burgesses, expel, echoing, centurion, toon, statistically, hiddenstructure,
# Nearest to heavy: gasp, positron, dilmun, zinc, evading, flees, determinants, proliferated,
# Nearest to square: vec, rotating, distances, housing, tip, points, lexington, vaz,
# Nearest to award: edom, played, pulitzer, garnering, nominated, peirce, internationalization, survivability,
# Nearest to woman: fertility, birth, male, dolly, bre, mortal, typhoid, shoah,
# Nearest to notes: loops, unedited, brackish, bigotry, descriptions, repertoire, traversed, neil,
# Nearest to ocean: shortwave, hurricane, pacific, highs, radios, sail, stations, kalahari,
#
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.0525 0.0233 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.0815 0.0227 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1105 0.0228 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.0638 0.0226 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1668 0.0226 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1167 0.0225 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1370 0.0226 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.0541 0.0227 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.0318 0.0226 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.0732 0.0225 sec/batch
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.0102 0.0226 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.0752 0.0225 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.0442 0.0227 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1000 0.0226 sec/batch
# Epoch 4/10 Iteration: 13500 Avg. Training loss: 4.0712 0.0205 sec/batch
# Epoch 4/10 Iteration: 13600 Avg. Training loss: 4.0709 0.0225 sec/batch
# Epoch 4/10 Iteration: 13700 Avg. Training loss: 4.0075 0.0226 sec/batch
# Epoch 4/10 Iteration: 13800 Avg. Training loss: 4.0330 0.0226 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 3.9961 0.0225 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 3.9762 0.0226 sec/batch
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 3.9970 0.0226 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0346 0.0225 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0188 0.0226 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0593 0.0226 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 3.9365 0.0227 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 3.9526 0.0225 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 3.9985 0.0227 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 3.9516 0.0225 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 3.9887 0.0226 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0166 0.0225 sec/batch
#
# Nearest to will: parting, fudge, feels, person, schwann, harmattan, promises, disappearing,
# Nearest to these: toriyama, explicitly, layering, flour, horizontal, lighter, pentecostalism, appropriate,
# Nearest to there: median, longbowmen, manner, stewed, trough, gigabit, alternates, aquinas,
# Nearest to with: cor, democratically, decrees, compatible, orleans, alam, momenta, offshoots,
# Nearest to for: gaming, alongside, bios, implemented, modification, function, cabling, encrypting,
# Nearest to about: ward, bioterrorism, monitoring, endothermic, cent, point, information, reassigned,
# Nearest to zero: two, three, one, eight, six, nine, four, na,
# Nearest to such: whereby, questionable, they, ts, dissimilar, competitors, mostly, evaluation,
# Nearest to units: edvac, bleaching, slowing, si, satsuma, gregorian, abiogenesis, unit,
# Nearest to issue: guerillas, expel, burgesses, echoing, statistically, toon, deliberation, jurisdictions,
# Nearest to heavy: gasp, salvo, positron, dilmun, evading, flees, zeppelin, proliferated,
# Nearest to square: lexington, housing, points, located, upstream, rotating, distances, vaz,
# Nearest to award: garnering, played, pulitzer, nominated, peirce, edom, literature, awards,
# Nearest to woman: birth, fertility, dolly, male, typhoid, mortal, shoah, children,
# Nearest to notes: loops, unedited, brackish, repertoire, traversed, accidentals, bigotry, descriptions,
# Nearest to ocean: shortwave, hurricane, pacific, sail, highs, radios, stations, kalahari,
#
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.9835 0.0233 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 3.9802 0.0226 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0526 0.0226 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0146 0.0226 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 3.9579 0.0225 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0164 0.0226 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0000 0.0227 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 3.9950 0.0227 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 3.9826 0.0226 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0129 0.0227 sec/batch
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 3.9754 0.0225 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0154 0.0227 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0102 0.0225 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0084 0.0225 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 3.9669 0.0226 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 3.9708 0.0226 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 3.9513 0.0226 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0288 0.0226 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0030 0.0226 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0881 0.0226 sec/batch
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0550 0.0226 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9795 0.0226 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 3.9621 0.0226 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 3.9983 0.0227 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 3.8749 0.0227 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 3.9875 0.0226 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 3.9974 0.0225 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 3.9630 0.0227 sec/batch
# Epoch 5/10 Iteration: 17900 Avg. Training loss: 4.0229 0.0048 sec/batch
# Epoch 5/10 Iteration: 18000 Avg. Training loss: 3.9668 0.0226 sec/batch
#
# Nearest to will: fudge, parting, person, harmattan, feels, shall, schwann, disappearing,
# Nearest to these: toriyama, explicitly, layering, lighter, appropriate, demographic, iai, flour,
# Nearest to there: median, longbowmen, trough, manner, stewed, gigabit, alternates, considered,
# Nearest to with: cor, democratically, compatible, decrees, maiden, alam, momenta, playback,
# Nearest to for: gaming, bios, granada, alongside, obtain, modification, cabling, implemented,
# Nearest to about: ward, bioterrorism, monitoring, information, cent, point, reverses, millions,
# Nearest to zero: two, three, one, eight, nine, four, five, six,
# Nearest to such: whereby, questionable, realistically, they, evaluation, ts, graphemes, gpcrs,
# Nearest to units: si, unit, satsuma, slowing, edvac, bleaching, infantry, abiogenesis,
# Nearest to issue: guerillas, expel, burgesses, statistically, echoing, toon, deliberation, hiddenstructure,
# Nearest to heavy: gasp, evading, zeppelin, dilmun, positron, proliferated, flees, salvo,
# Nearest to square: lexington, housing, points, upstream, located, sisak, rebounds, commemorating,
# Nearest to award: garnering, nominated, awards, pulitzer, literature, academy, hugo, played,
# Nearest to woman: fertility, birth, dolly, male, mortal, shoah, children, typhoid,
# Nearest to notes: loops, unedited, brackish, accidentals, traversed, repertoire, bigotry, emphasise,
# Nearest to ocean: shortwave, sail, pacific, hurricane, highs, radios, stations, kalahari,
#
# Epoch 5/10 Iteration: 18100 Avg. Training loss: 3.9437 0.0233 sec/batch
# Epoch 5/10 Iteration: 18200 Avg. Training loss: 3.9275 0.0226 sec/batch
# Epoch 5/10 Iteration: 18300 Avg. Training loss: 3.9306 0.0225 sec/batch
# Epoch 5/10 Iteration: 18400 Avg. Training loss: 3.9009 0.0226 sec/batch
# Epoch 5/10 Iteration: 18500 Avg. Training loss: 3.9256 0.0226 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 3.8938 0.0225 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9997 0.0226 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9425 0.0225 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9671 0.0226 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.8416 0.0225 sec/batch
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9171 0.0227 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.8871 0.0225 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.8631 0.0225 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9453 0.0226 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9760 0.0226 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9122 0.0226 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9504 0.0226 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9665 0.0227 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.8805 0.0225 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9254 0.0227 sec/batch
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9419 0.0226 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9516 0.0226 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9115 0.0226 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9872 0.0226 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 3.8889 0.0226 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9358 0.0225 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9263 0.0226 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9635 0.0227 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9187 0.0227 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9070 0.0226 sec/batch
#
# Nearest to will: fudge, harmattan, parting, person, shall, feels, schwann, recites,
# Nearest to these: toriyama, mainline, explicitly, demographic, appropriate, flour, ebola, well,
# Nearest to there: median, longbowmen, trough, considered, aquinas, manner, gigabit, stewed,
# Nearest to with: cor, decrees, the, democratically, offshoots, uplifting, compatible, maiden,
# Nearest to for: gaming, women, modification, the, obtain, bios, granada, colby,
# Nearest to about: information, ward, monitoring, bioterrorism, millions, cent, point, reverses,
# Nearest to zero: two, one, three, eight, nine, five, six, four,
# Nearest to such: whereby, they, are, questionable, realistically, gpcrs, graphemes, lon,
# Nearest to units: si, unit, infantry, satsuma, mechanised, edvac, simcoe, abiogenesis,
# Nearest to issue: guerillas, expel, echoing, statistically, burgesses, toon, vinge, hiddenstructure,
# Nearest to heavy: gasp, positron, zeppelin, evading, proliferated, dilmun, estonians, determinants,
# Nearest to square: lexington, upstream, points, sisak, commemorating, housing, located, rebounds,
# Nearest to award: garnering, awards, nominated, pulitzer, hugo, literature, emmy, best,
# Nearest to woman: birth, fertility, male, children, dolly, shoah, infant, mortal,
# Nearest to notes: loops, unedited, accidentals, traversed, joints, repertoire, brackish, progressions,
# Nearest to ocean: shortwave, pacific, sail, hurricane, radios, stations, kalahari, highs,
#
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.8856 0.0234 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9137 0.0228 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9023 0.0225 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0027 0.0226 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0339 0.0227 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0024 0.0227 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9206 0.0227 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.8827 0.0227 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9171 0.0225 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.8215 0.0227 sec/batch
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9339 0.0225 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 3.9203 0.0227 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 3.9068 0.0226 sec/batch
# Epoch 6/10 Iteration: 22400 Avg. Training loss: 3.9500 0.0117 sec/batch
# Epoch 6/10 Iteration: 22500 Avg. Training loss: 3.8919 0.0227 sec/batch
# Epoch 6/10 Iteration: 22600 Avg. Training loss: 3.8940 0.0226 sec/batch
# Epoch 6/10 Iteration: 22700 Avg. Training loss: 3.9150 0.0226 sec/batch
# Epoch 6/10 Iteration: 22800 Avg. Training loss: 3.8459 0.0225 sec/batch
# Epoch 6/10 Iteration: 22900 Avg. Training loss: 3.8785 0.0227 sec/batch
# Epoch 6/10 Iteration: 23000 Avg. Training loss: 3.8157 0.0225 sec/batch
# Epoch 6/10 Iteration: 23100 Avg. Training loss: 3.9149 0.0227 sec/batch
# Epoch 6/10 Iteration: 23200 Avg. Training loss: 3.9145 0.0226 sec/batch
# Epoch 6/10 Iteration: 23300 Avg. Training loss: 3.9305 0.0226 sec/batch
# Epoch 6/10 Iteration: 23400 Avg. Training loss: 3.8907 0.0226 sec/batch
# Epoch 6/10 Iteration: 23500 Avg. Training loss: 3.8141 0.0227 sec/batch
# Epoch 6/10 Iteration: 23600 Avg. Training loss: 3.8738 0.0225 sec/batch
# Epoch 6/10 Iteration: 23700 Avg. Training loss: 3.8157 0.0225 sec/batch
# Epoch 6/10 Iteration: 23800 Avg. Training loss: 3.8723 0.0227 sec/batch
# Epoch 6/10 Iteration: 23900 Avg. Training loss: 3.8933 0.0225 sec/batch
# Epoch 6/10 Iteration: 24000 Avg. Training loss: 3.8792 0.0227 sec/batch
#
# Nearest to will: fudge, person, parting, shall, harmattan, niv, feels, recites,
# Nearest to these: toriyama, demographic, mainline, well, appropriate, iai, layering, sch,
# Nearest to there: median, longbowmen, considered, manner, trough, aquinas, two, living,
# Nearest to with: the, cor, compatible, changed, decrees, bradman, rom, couple,
# Nearest to for: the, to, gaming, from, and, women, obtain, bios,
# Nearest to about: monitoring, ward, information, cent, millions, page, toast, reverses,
# Nearest to zero: two, three, one, eight, five, six, four, nine,
# Nearest to such: are, they, questionable, gpcrs, also, politicians, whereby, evaluation,
# Nearest to units: si, unit, edvac, mechanised, infantry, abiogenesis, liter, satsuma,
# Nearest to issue: guerillas, statistically, expel, echoing, burgesses, toon, confusion, full,
# Nearest to heavy: zeppelin, evading, proliferated, gasp, positron, salvo, dilmun, estonians,
# Nearest to square: lexington, points, upstream, metres, sisak, located, housing, rotating,
# Nearest to award: awards, nominated, pulitzer, garnering, literature, academy, emmy, oscars,
# Nearest to woman: birth, fertility, shoah, dolly, children, male, typhoid, wally,
# Nearest to notes: loops, brackish, accidentals, traversed, unedited, progressions, repertoire, joints,
# Nearest to ocean: shortwave, sail, pacific, tsunami, radios, hurricane, kalahari, highs,
#
# Epoch 6/10 Iteration: 24100 Avg. Training loss: 3.8545 0.0232 sec/batch
# Epoch 6/10 Iteration: 24200 Avg. Training loss: 3.9076 0.0225 sec/batch
# Epoch 6/10 Iteration: 24300 Avg. Training loss: 3.9062 0.0226 sec/batch
# Epoch 6/10 Iteration: 24400 Avg. Training loss: 3.8659 0.0226 sec/batch
# Epoch 6/10 Iteration: 24500 Avg. Training loss: 3.8762 0.0226 sec/batch
# Epoch 6/10 Iteration: 24600 Avg. Training loss: 3.9227 0.0227 sec/batch
# Epoch 6/10 Iteration: 24700 Avg. Training loss: 3.9083 0.0224 sec/batch
# Epoch 6/10 Iteration: 24800 Avg. Training loss: 3.8556 0.0226 sec/batch
# Epoch 6/10 Iteration: 24900 Avg. Training loss: 3.8503 0.0227 sec/batch
# Epoch 6/10 Iteration: 25000 Avg. Training loss: 3.9292 0.0225 sec/batch
# Epoch 6/10 Iteration: 25100 Avg. Training loss: 3.8988 0.0226 sec/batch
# Epoch 6/10 Iteration: 25200 Avg. Training loss: 3.8897 0.0227 sec/batch
# Epoch 6/10 Iteration: 25300 Avg. Training loss: 3.9074 0.0226 sec/batch
# Epoch 6/10 Iteration: 25400 Avg. Training loss: 3.8688 0.0225 sec/batch
# Epoch 6/10 Iteration: 25500 Avg. Training loss: 3.8829 0.0225 sec/batch
# Epoch 6/10 Iteration: 25600 Avg. Training loss: 3.8782 0.0226 sec/batch
# Epoch 6/10 Iteration: 25700 Avg. Training loss: 3.9016 0.0227 sec/batch
# Epoch 6/10 Iteration: 25800 Avg. Training loss: 3.9118 0.0227 sec/batch
# Epoch 6/10 Iteration: 25900 Avg. Training loss: 4.0075 0.0225 sec/batch
# Epoch 6/10 Iteration: 26000 Avg. Training loss: 3.9196 0.0227 sec/batch
# Epoch 6/10 Iteration: 26100 Avg. Training loss: 3.9382 0.0226 sec/batch
# Epoch 6/10 Iteration: 26200 Avg. Training loss: 3.8114 0.0227 sec/batch
# Epoch 6/10 Iteration: 26300 Avg. Training loss: 3.8043 0.0226 sec/batch
# Epoch 6/10 Iteration: 26400 Avg. Training loss: 3.8703 0.0227 sec/batch
# Epoch 6/10 Iteration: 26500 Avg. Training loss: 3.8322 0.0225 sec/batch
# Epoch 6/10 Iteration: 26600 Avg. Training loss: 3.8756 0.0228 sec/batch
# Epoch 6/10 Iteration: 26700 Avg. Training loss: 3.8688 0.0226 sec/batch
# Epoch 6/10 Iteration: 26800 Avg. Training loss: 3.8961 0.0226 sec/batch
# Epoch 7/10 Iteration: 26900 Avg. Training loss: 3.8827 0.0183 sec/batch
# Epoch 7/10 Iteration: 27000 Avg. Training loss: 3.8621 0.0225 sec/batch
#
# Nearest to will: fudge, harmattan, person, niv, recites, schwann, parting, shankar,
# Nearest to these: demographic, toriyama, iai, well, sch, mainline, incompatibilities, approximations,
# Nearest to there: median, longbowmen, considered, manner, controversial, living, rabbinic, latino,
# Nearest to with: the, cor, compatible, couple, ayn, offshoots, cai, is,
# Nearest to for: the, and, to, from, gaming, obtain, bios, modification,
# Nearest to about: monitoring, information, ward, cent, page, millions, bioterrorism, facts,
# Nearest to zero: two, three, one, four, eight, five, nine, six,
# Nearest to such: are, also, questionable, they, scholasticus, thematically, evaluation, mosques,
# Nearest to units: unit, si, abiogenesis, infantry, mechanised, liter, edvac, bipm,
# Nearest to issue: expel, statistically, echoing, guerillas, burgesses, full, confusion, toon,
# Nearest to heavy: zeppelin, evading, proliferated, expressing, dilmun, positron, gasp, estonians,
# Nearest to square: lexington, sisak, commemorating, parks, housing, metres, located, tabulating,
# Nearest to award: awards, nominated, academy, garnering, oscars, emmy, hugo, literature,
# Nearest to woman: birth, fertility, shoah, male, dolly, children, adjective, mortal,
# Nearest to notes: loops, accidentals, progressions, brackish, traversed, unedited, tuned, emphasise,
# Nearest to ocean: shortwave, sail, pacific, tsunami, radios, kalahari, stations, submarine,
#
# Epoch 7/10 Iteration: 27100 Avg. Training loss: 3.8449 0.0234 sec/batch
# Epoch 7/10 Iteration: 27200 Avg. Training loss: 3.8743 0.0226 sec/batch
# Epoch 7/10 Iteration: 27300 Avg. Training loss: 3.8299 0.0225 sec/batch
# Epoch 7/10 Iteration: 27400 Avg. Training loss: 3.8111 0.0225 sec/batch
# Epoch 7/10 Iteration: 27500 Avg. Training loss: 3.8134 0.0228 sec/batch
# Epoch 7/10 Iteration: 27600 Avg. Training loss: 3.8510 0.0225 sec/batch
# Epoch 7/10 Iteration: 27700 Avg. Training loss: 3.8827 0.0227 sec/batch
# Epoch 7/10 Iteration: 27800 Avg. Training loss: 3.8759 0.0226 sec/batch
# Epoch 7/10 Iteration: 27900 Avg. Training loss: 3.8380 0.0226 sec/batch
# Epoch 7/10 Iteration: 28000 Avg. Training loss: 3.7953 0.0228 sec/batch
# Epoch 7/10 Iteration: 28100 Avg. Training loss: 3.8525 0.0225 sec/batch
# Epoch 7/10 Iteration: 28200 Avg. Training loss: 3.7586 0.0226 sec/batch
# Epoch 7/10 Iteration: 28300 Avg. Training loss: 3.8310 0.0225 sec/batch
# Epoch 7/10 Iteration: 28400 Avg. Training loss: 3.8629 0.0226 sec/batch
# Epoch 7/10 Iteration: 28500 Avg. Training loss: 3.8582 0.0226 sec/batch
# Epoch 7/10 Iteration: 28600 Avg. Training loss: 3.8236 0.0226 sec/batch
# Epoch 7/10 Iteration: 28700 Avg. Training loss: 3.8854 0.0225 sec/batch
# Epoch 7/10 Iteration: 28800 Avg. Training loss: 3.8828 0.0227 sec/batch
# Epoch 7/10 Iteration: 28900 Avg. Training loss: 3.8552 0.0225 sec/batch
# Epoch 7/10 Iteration: 29000 Avg. Training loss: 3.8275 0.0226 sec/batch
# Epoch 7/10 Iteration: 29100 Avg. Training loss: 3.8540 0.0226 sec/batch
# Epoch 7/10 Iteration: 29200 Avg. Training loss: 3.8291 0.0226 sec/batch
# Epoch 7/10 Iteration: 29300 Avg. Training loss: 3.8636 0.0226 sec/batch
# Epoch 7/10 Iteration: 29400 Avg. Training loss: 3.8416 0.0225 sec/batch
# Epoch 7/10 Iteration: 29500 Avg. Training loss: 3.8415 0.0226 sec/batch
# Epoch 7/10 Iteration: 29600 Avg. Training loss: 3.8711 0.0226 sec/batch
# Epoch 7/10 Iteration: 29700 Avg. Training loss: 3.8593 0.0227 sec/batch
# Epoch 7/10 Iteration: 29800 Avg. Training loss: 3.8441 0.0224 sec/batch
# Epoch 7/10 Iteration: 29900 Avg. Training loss: 3.8186 0.0225 sec/batch
# Epoch 7/10 Iteration: 30000 Avg. Training loss: 3.8221 0.0226 sec/batch
#
# Nearest to will: fudge, harmattan, person, niv, shall, judgement, schwann, recites,
# Nearest to these: well, many, demographic, included, orators, mainline, benediction, toriyama,
# Nearest to there: considered, median, longbowmen, two, under, living, bioko, six,
# Nearest to with: the, cor, in, is, couple, a, of, offshoots,
# Nearest to for: the, and, to, is, of, from, a, an,
# Nearest to about: information, monitoring, page, millions, ward, bioterrorism, facts, utter,
# Nearest to zero: two, one, three, five, eight, six, nine, four,
# Nearest to such: are, also, they, gpcrs, questionable, some, scholasticus, politicians,
# Nearest to units: unit, si, infantry, abiogenesis, edvac, mechanised, liter, bipm,
# Nearest to issue: echoing, statistically, expel, full, confusion, guerillas, burgesses, citing,
# Nearest to heavy: zeppelin, proliferated, evading, expressing, positron, estonians, synthesizing, dilmun,
# Nearest to square: commemorating, lexington, sisak, syndicate, parks, points, metres, housing,
# Nearest to award: awards, nominated, hugo, academy, literature, oscars, emmy, garnering,
# Nearest to woman: birth, fertility, shoah, male, adjective, dolly, she, children,
# Nearest to notes: accidentals, brackish, progressions, traversed, unedited, loops, joints, diplodocus,
# Nearest to ocean: shortwave, sail, pacific, tsunami, radios, kalahari, submarine, cocos,
#
# Epoch 7/10 Iteration: 30100 Avg. Training loss: 3.8128 0.0233 sec/batch
# Epoch 7/10 Iteration: 30200 Avg. Training loss: 3.9213 0.0227 sec/batch
# Epoch 7/10 Iteration: 30300 Avg. Training loss: 3.8532 0.0227 sec/batch
# Epoch 7/10 Iteration: 30400 Avg. Training loss: 3.9525 0.0227 sec/batch
# Epoch 7/10 Iteration: 30500 Avg. Training loss: 3.9136 0.0226 sec/batch
# Epoch 7/10 Iteration: 30600 Avg. Training loss: 3.8586 0.0229 sec/batch
# Epoch 7/10 Iteration: 30700 Avg. Training loss: 3.8015 0.0225 sec/batch
# Epoch 7/10 Iteration: 30800 Avg. Training loss: 3.8357 0.0226 sec/batch
# Epoch 7/10 Iteration: 30900 Avg. Training loss: 3.7634 0.0225 sec/batch
# Epoch 7/10 Iteration: 31000 Avg. Training loss: 3.8502 0.0226 sec/batch
# Epoch 7/10 Iteration: 31100 Avg. Training loss: 3.8525 0.0225 sec/batch
# Epoch 7/10 Iteration: 31200 Avg. Training loss: 3.8249 0.0227 sec/batch
# Epoch 8/10 Iteration: 31300 Avg. Training loss: 3.8747 0.0025 sec/batch
# Epoch 8/10 Iteration: 31400 Avg. Training loss: 3.8513 0.0227 sec/batch
# Epoch 8/10 Iteration: 31500 Avg. Training loss: 3.8408 0.0227 sec/batch
# Epoch 8/10 Iteration: 31600 Avg. Training loss: 3.8362 0.0226 sec/batch
# Epoch 8/10 Iteration: 31700 Avg. Training loss: 3.8211 0.0226 sec/batch
# Epoch 8/10 Iteration: 31800 Avg. Training loss: 3.7890 0.0225 sec/batch
# Epoch 8/10 Iteration: 31900 Avg. Training loss: 3.8578 0.0226 sec/batch
# Epoch 8/10 Iteration: 32000 Avg. Training loss: 3.7581 0.0227 sec/batch
# Epoch 8/10 Iteration: 32100 Avg. Training loss: 3.8420 0.0226 sec/batch
# Epoch 8/10 Iteration: 32200 Avg. Training loss: 3.8183 0.0227 sec/batch
# Epoch 8/10 Iteration: 32300 Avg. Training loss: 3.8436 0.0226 sec/batch
# Epoch 8/10 Iteration: 32400 Avg. Training loss: 3.7381 0.0227 sec/batch
# Epoch 8/10 Iteration: 32500 Avg. Training loss: 3.8132 0.0227 sec/batch
# Epoch 8/10 Iteration: 32600 Avg. Training loss: 3.7574 0.0227 sec/batch
# Epoch 8/10 Iteration: 32700 Avg. Training loss: 3.7487 0.0226 sec/batch
# Epoch 8/10 Iteration: 32800 Avg. Training loss: 3.8038 0.0227 sec/batch
# Epoch 8/10 Iteration: 32900 Avg. Training loss: 3.8337 0.0225 sec/batch
# Epoch 8/10 Iteration: 33000 Avg. Training loss: 3.7908 0.0229 sec/batch
#
# Nearest to will: person, fudge, harmattan, shall, niv, surely, is, ike,
# Nearest to these: well, included, toriyama, many, sized, incompatibilities, iai, mainline,
# Nearest to there: considered, median, longbowmen, under, living, are, two, bradycardia,
# Nearest to with: the, in, a, is, of, which, couple, and,
# Nearest to for: the, and, to, also, a, from, is, in,
# Nearest to about: information, monitoring, page, millions, collected, measuring, ward, cent,
# Nearest to zero: two, three, one, five, six, eight, four, nine,
# Nearest to such: are, also, some, many, with, gpcrs, questionable, amoxicillin,
# Nearest to units: unit, si, infantry, abiogenesis, edvac, bipm, liter, mechanised,
# Nearest to issue: statistically, full, echoing, expel, confusion, guerillas, daily, toon,
# Nearest to heavy: zeppelin, evading, proliferated, expressing, positron, swine, dilmun, estonians,
# Nearest to square: metres, sisak, commemorating, lexington, points, parks, syndicate, upstream,
# Nearest to award: awards, nominated, academy, literature, hugo, oscars, garnering, emmy,
# Nearest to woman: birth, fertility, shoah, dolly, adjective, mitford, children, typhoid,
# Nearest to notes: accidentals, progressions, unedited, traversed, loops, brackish, joints, menelik,
# Nearest to ocean: shortwave, sail, pacific, submarine, tsunami, radios, intersputnik, kalahari,
#
# Epoch 8/10 Iteration: 33100 Avg. Training loss: 3.8263 0.0234 sec/batch
# Epoch 8/10 Iteration: 33200 Avg. Training loss: 3.8705 0.0226 sec/batch
# Epoch 8/10 Iteration: 33300 Avg. Training loss: 3.7994 0.0227 sec/batch
# Epoch 8/10 Iteration: 33400 Avg. Training loss: 3.8154 0.0224 sec/batch
# Epoch 8/10 Iteration: 33500 Avg. Training loss: 3.8458 0.0226 sec/batch
# Epoch 8/10 Iteration: 33600 Avg. Training loss: 3.8065 0.0226 sec/batch
# Epoch 8/10 Iteration: 33700 Avg. Training loss: 3.8428 0.0227 sec/batch
# Epoch 8/10 Iteration: 33800 Avg. Training loss: 3.8323 0.0227 sec/batch
# Epoch 8/10 Iteration: 33900 Avg. Training loss: 3.8397 0.0226 sec/batch
# Epoch 8/10 Iteration: 34000 Avg. Training loss: 3.8066 0.0228 sec/batch
# Epoch 8/10 Iteration: 34100 Avg. Training loss: 3.8355 0.0225 sec/batch
# Epoch 8/10 Iteration: 34200 Avg. Training loss: 3.8585 0.0226 sec/batch
# Epoch 8/10 Iteration: 34300 Avg. Training loss: 3.8401 0.0227 sec/batch
# Epoch 8/10 Iteration: 34400 Avg. Training loss: 3.8044 0.0227 sec/batch
# Epoch 8/10 Iteration: 34500 Avg. Training loss: 3.7749 0.0225 sec/batch
# Epoch 8/10 Iteration: 34600 Avg. Training loss: 3.7985 0.0227 sec/batch
# Epoch 8/10 Iteration: 34700 Avg. Training loss: 3.8629 0.0226 sec/batch
# Epoch 8/10 Iteration: 34800 Avg. Training loss: 3.8738 0.0226 sec/batch
# Epoch 8/10 Iteration: 34900 Avg. Training loss: 3.9045 0.0226 sec/batch
# Epoch 8/10 Iteration: 35000 Avg. Training loss: 3.8527 0.0225 sec/batch
# Epoch 8/10 Iteration: 35100 Avg. Training loss: 3.8184 0.0226 sec/batch
# Epoch 8/10 Iteration: 35200 Avg. Training loss: 3.7715 0.0227 sec/batch
# Epoch 8/10 Iteration: 35300 Avg. Training loss: 3.8026 0.0226 sec/batch
# Epoch 8/10 Iteration: 35400 Avg. Training loss: 3.7283 0.0226 sec/batch
# Epoch 8/10 Iteration: 35500 Avg. Training loss: 3.8538 0.0226 sec/batch
# Epoch 8/10 Iteration: 35600 Avg. Training loss: 3.8415 0.0226 sec/batch
# Epoch 8/10 Iteration: 35700 Avg. Training loss: 3.8190 0.0226 sec/batch
# Epoch 9/10 Iteration: 35800 Avg. Training loss: 3.8824 0.0093 sec/batch
# Epoch 9/10 Iteration: 35900 Avg. Training loss: 3.8077 0.0228 sec/batch
# Epoch 9/10 Iteration: 36000 Avg. Training loss: 3.7978 0.0228 sec/batch
#
# Nearest to will: harmattan, fudge, person, shall, niv, schwann, is, disappearing,
# Nearest to these: included, many, toriyama, well, sized, incompatibilities, ones, sch,
# Nearest to there: considered, median, longbowmen, in, have, bradycardia, are, rrna,
# Nearest to with: the, a, in, is, and, of, gravitation, couple,
# Nearest to for: the, and, also, is, to, in, of, a,
# Nearest to about: information, monitoring, bunch, page, measuring, cent, have, tsiolkovsky,
# Nearest to zero: two, three, one, five, four, eight, six, nine,
# Nearest to such: are, also, many, some, they, often, gpcrs, examples,
# Nearest to units: unit, si, infantry, bipm, liter, abiogenesis, metre, edvac,
# Nearest to issue: statistically, echoing, full, expel, confusion, abraxas, overwhelmingly, humanitarian,
# Nearest to heavy: zeppelin, proliferated, expressing, evading, positron, swine, violence, cx,
# Nearest to square: sisak, metres, points, commemorating, parks, lexington, londinium, syndicate,
# Nearest to award: awards, nominated, academy, hugo, literature, oscars, garnering, emmy,
# Nearest to woman: birth, fertility, shoah, adjective, sweetheart, mitford, typhoid, mortal,
# Nearest to notes: accidentals, progressions, menelik, traversed, urging, diminished, joints, brackish,
# Nearest to ocean: shortwave, sail, pacific, tsunami, submarine, radios, intersputnik, cocos,
#
# Epoch 9/10 Iteration: 36100 Avg. Training loss: 3.8188 0.0233 sec/batch
# Epoch 9/10 Iteration: 36200 Avg. Training loss: 3.7752 0.0226 sec/batch
# Epoch 9/10 Iteration: 36300 Avg. Training loss: 3.7824 0.0227 sec/batch
# Epoch 9/10 Iteration: 36400 Avg. Training loss: 3.7672 0.0226 sec/batch
# Epoch 9/10 Iteration: 36500 Avg. Training loss: 3.8132 0.0226 sec/batch
# Epoch 9/10 Iteration: 36600 Avg. Training loss: 3.8098 0.0226 sec/batch
# Epoch 9/10 Iteration: 36700 Avg. Training loss: 3.8174 0.0225 sec/batch
# Epoch 9/10 Iteration: 36800 Avg. Training loss: 3.8278 0.0226 sec/batch
# Epoch 9/10 Iteration: 36900 Avg. Training loss: 3.7212 0.0225 sec/batch
# Epoch 9/10 Iteration: 37000 Avg. Training loss: 3.7750 0.0226 sec/batch
# Epoch 9/10 Iteration: 37100 Avg. Training loss: 3.7515 0.0225 sec/batch
# Epoch 9/10 Iteration: 37200 Avg. Training loss: 3.7826 0.0226 sec/batch
# Epoch 9/10 Iteration: 37300 Avg. Training loss: 3.8083 0.0225 sec/batch
# Epoch 9/10 Iteration: 37400 Avg. Training loss: 3.8056 0.0226 sec/batch
# Epoch 9/10 Iteration: 37500 Avg. Training loss: 3.8140 0.0226 sec/batch
# Epoch 9/10 Iteration: 37600 Avg. Training loss: 3.8178 0.0224 sec/batch
# Epoch 9/10 Iteration: 37700 Avg. Training loss: 3.8263 0.0227 sec/batch
# Epoch 9/10 Iteration: 37800 Avg. Training loss: 3.7748 0.0226 sec/batch
# Epoch 9/10 Iteration: 37900 Avg. Training loss: 3.7949 0.0227 sec/batch
# Epoch 9/10 Iteration: 38000 Avg. Training loss: 3.8386 0.0226 sec/batch
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 3.8236 0.0226 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.7555 0.0225 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8338 0.0227 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.8046 0.0226 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.7815 0.0227 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8445 0.0227 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8013 0.0227 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8293 0.0227 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.7716 0.0225 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.7711 0.0227 sec/batch
#
# Nearest to will: harmattan, fudge, niv, person, shall, is, judgement, chicks,
# Nearest to these: included, well, many, the, have, sized, incompatibilities, several,
# Nearest to there: considered, median, longbowmen, that, are, two, have, under,
# Nearest to with: the, of, in, a, is, and, to, which,
# Nearest to for: the, to, and, is, in, also, of, on,
# Nearest to about: information, monitoring, page, measuring, have, collected, zero, bunch,
# Nearest to zero: two, one, three, five, eight, six, four, nine,
# Nearest to such: are, of, also, some, many, gpcrs, they, with,
# Nearest to units: unit, si, infantry, bipm, abiogenesis, regiments, edvac, metre,
# Nearest to issue: statistically, echoing, full, citing, abraxas, humanitarian, overwhelmingly, daily,
# Nearest to heavy: zeppelin, expressing, proliferated, evading, cx, synthesizing, positron, swine,
# Nearest to square: metres, sisak, points, commemorating, lexington, syndicate, londinium, smallest,
# Nearest to award: awards, nominated, hugo, academy, literature, pulitzer, emmy, awarded,
# Nearest to woman: birth, fertility, shoah, adjective, she, typhoid, mitford, children,
# Nearest to notes: accidentals, menelik, progressions, urging, diminished, tunings, traversed, unedited,
# Nearest to ocean: shortwave, pacific, sail, tsunami, submarine, radios, intersputnik, cocos,
#
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8308 0.0233 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8179 0.0226 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8870 0.0227 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8706 0.0226 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8704 0.0226 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.7756 0.0226 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.7116 0.0225 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8373 0.0225 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.7205 0.0226 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8361 0.0225 sec/batch
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.7875 0.0226 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8130 0.0225 sec/batch
# Epoch 10/10 Iteration: 40300 Avg. Training loss: 3.8119 0.0162 sec/batch
# Epoch 10/10 Iteration: 40400 Avg. Training loss: 3.8150 0.0226 sec/batch
# Epoch 10/10 Iteration: 40500 Avg. Training loss: 3.7889 0.0225 sec/batch
# Epoch 10/10 Iteration: 40600 Avg. Training loss: 3.8371 0.0227 sec/batch
# Epoch 10/10 Iteration: 40700 Avg. Training loss: 3.7397 0.0224 sec/batch
# Epoch 10/10 Iteration: 40800 Avg. Training loss: 3.7926 0.0228 sec/batch
# Epoch 10/10 Iteration: 40900 Avg. Training loss: 3.7397 0.0224 sec/batch
# Epoch 10/10 Iteration: 41000 Avg. Training loss: 3.7988 0.0226 sec/batch
# Epoch 10/10 Iteration: 41100 Avg. Training loss: 3.8108 0.0225 sec/batch
# Epoch 10/10 Iteration: 41200 Avg. Training loss: 3.7931 0.0228 sec/batch
# Epoch 10/10 Iteration: 41300 Avg. Training loss: 3.8042 0.0226 sec/batch
# Epoch 10/10 Iteration: 41400 Avg. Training loss: 3.6951 0.0226 sec/batch
# Epoch 10/10 Iteration: 41500 Avg. Training loss: 3.7340 0.0225 sec/batch
# Epoch 10/10 Iteration: 41600 Avg. Training loss: 3.6963 0.0226 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.7637 0.0224 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.7909 0.0225 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.7662 0.0226 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.7661 0.0225 sec/batch
#
# Nearest to will: fudge, shall, is, niv, person, harmattan, judgement, save,
# Nearest to these: included, many, well, have, sized, incompatibilities, several, ones,
# Nearest to there: considered, are, that, longbowmen, median, have, and, in,
# Nearest to with: the, in, a, and, is, of, first, as,
# Nearest to for: the, and, in, also, is, to, a, of,
# Nearest to about: information, monitoring, collected, page, prep, measuring, bunch, magazine,
# Nearest to zero: two, one, three, five, six, four, eight, nine,
# Nearest to such: also, many, are, some, with, in, of, examples,
# Nearest to units: unit, si, infantry, bipm, mechanised, metre, edvac, liter,
# Nearest to issue: full, statistically, echoing, dfs, humanitarian, daily, abraxas, greenfacts,
# Nearest to heavy: zeppelin, expressing, proliferated, cx, evading, swine, positron, lise,
# Nearest to square: metres, sisak, points, encourage, commemorating, lexington, cube, parks,
# Nearest to award: awards, nominated, academy, awarded, received, literature, hugo, pulitzer,
# Nearest to woman: birth, fertility, shoah, mitford, typhoid, adjective, children, sweetheart,
# Nearest to notes: menelik, accidentals, diminished, progressions, urging, joints, fifths, tunings,
# Nearest to ocean: shortwave, pacific, tsunami, sail, submarine, radios, intersputnik, kalahari,
#
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8325 0.0233 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.7876 0.0225 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7572 0.0225 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7699 0.0225 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8014 0.0226 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8366 0.0226 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.7485 0.0225 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7595 0.0226 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7783 0.0225 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8027 0.0226 sec/batch
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7802 0.0224 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.7918 0.0226 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.7799 0.0225 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.7486 0.0225 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7449 0.0225 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8790 0.0227 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.7703 0.0226 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8996 0.0226 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8287 0.0227 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8154 0.0226 sec/batch
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.7327 0.0228 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.7437 0.0226 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.7461 0.0225 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.7780 0.0224 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8100 0.0226 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.7624 0.0225 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8043 0.0226 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
